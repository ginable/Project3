# %% [markdown]
# ## train.ipynb
# 1. 기본 설정
# 2. Xception 모델
# 2-1. Xception 구현
# 2-2. Pretrained Weight
# 3. 훈련(Fine Tuning)
# 3-1. 전처리
# 3-2. Train/Validate 함수
# 3-3. 훈련

# %%
# !nvidia-smi
# Out:
# Sun Dec 15 14:17:25 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.36                 Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   48C    P3             52W /  220W |    7375MiB /  12282MiB |     39%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       372    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A      2592    C+G   ...on\131.0.2903.86\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A      2948    C+G   ...on\HEX\Creative Cloud UI Helper.exe      N/A      |
# |    0   N/A  N/A      6332    C+G   ...Office 2022\HOffice120\Bin\Hpdf.exe      N/A      |
# |    0   N/A  N/A      6516    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A      8136    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     10848    C+G   ...on\131.0.2903.86\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     12036    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     12624    C+G   ...aa84af5-ecd1-4a91-9005-12d70f3fcc68      N/A      |
# |    0   N/A  N/A     13164    C+G   ...n\NVIDIA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A     14204    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     14476    C+G   ...B\system_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A     14920    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     15968    C+G   ...Office 2022\HOffice120\Bin\Hpdf.exe      N/A      |
# |    0   N/A  N/A     16316    C+G   ...of Legends\LeagueClientUxRender.exe      N/A      |
# |    0   N/A  N/A     17256    C+G   ...n\NVIDIA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A     17820    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     18164    C+G   ...\Office 2022\HOffice120\Bin\Hwp.exe      N/A      |
# |    0   N/A  N/A     18684    C+G   ...s\System32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A     18956    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     19244    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     20076    C+G   ...ejd91yc\AdobeNotificationClient.exe      N/A      |
# |    0   N/A  N/A     20080      C   ...\anaconda3\envs\deepfake\python.exe      N/A      |
# |    0   N/A  N/A     21944    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     22440    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     24180    C+G   ... Legends\Game\League of Legends.exe      N/A      |
# |    0   N/A  N/A     27416    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     29216    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 1. 기본 설정

# %%
import easydict
import os
import sys
from PIL import Image
import tqdm
import shutil

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision.transforms as transforms
import torch.utils.data as data
import torch.backends.cudnn as cudnn
from torchvision import transforms

# %%
import os

# 현재 작업 디렉토리 확인
current_directory = os.getcwd()
print(f"현재 작업 디렉토리: {current_directory}")

# 이동할 디렉토리 설정
target_directory = r"D:\01.deepfake"

# 디렉토리 이동
try:
    os.chdir(target_directory)
    print(f"디렉토리를 이동했습니다: {os.getcwd()}")
except FileNotFoundError:
    print(f"지정된 경로가 존재하지 않습니다: {target_directory}")
except PermissionError:
    print(f"지정된 경로에 접근할 권한이 없습니다: {target_directory}")
# Out:
# 현재 작업 디렉토리: D:\01.deepfake
# 디렉토리를 이동했습니다: D:\01.deepfake

# %%
cudnn.benchmark = True

args = easydict.EasyDict({
    "gpu": 0,  # 현재 사용 가능한 GPU 번호
    "num_workers": 4,  # 일반 PC에 맞게 32에서 4로 조정

    # 실제 데이터 경로로 수정
    "root": "D:/01.deepfake/dfdc_train_part_0 - 복사본",
    "train_list": "D:/01.deepfake/dfdc_train_part_0 - 복사본/train_list_1st.txt",
    "valid_list": "D:/01.deepfake/dfdc_train_part_0 - 복사본/test_list_1st.txt",

    # 학습 관련 파라미터
    "learning_rate": 0.001,
    "num_epochs": 1,
    "batch_size": 16,  # GPU 메모리에 맞게 32에서 16으로 조정

    # 모델 저장 경로
    "save_fn": "D:/01.deepfake/models/deepfake_c0_xception_tuned.pth.tar",
})

# 필요한 디렉토리 생성
os.makedirs("D:/01.deepfake/models", exist_ok=True)

# train_list_1st.txt와 test_list_1st.txt 파일이 없다면 생성하는 코드 추가
def create_data_list_files():
    train_images = []  # 학습 이미지 경로 리스트
    test_images = []   # 테스트 이미지 경로 리스트
    
    # train_list_1st.txt 생성
    with open(args.train_list, 'w') as f:
        for img_path in train_images:
            label = 0  # 또는 1 (실제 라벨에 따라)
            f.write(f"{img_path} {label}\n")
    
    # test_list_1st.txt 생성
    with open(args.valid_list, 'w') as f:
        for img_path in test_images:
            label = 0  # 또는 1 (실제 라벨에 따라)
            f.write(f"{img_path} {label}\n")

# 파일 존재 여부 확인 전에 리스트 파일 생성
if not os.path.isfile(args.train_list) or not os.path.isfile(args.valid_list):
    create_data_list_files()

# 경로 확인
assert os.path.isfile(args.train_list), f'Training list not found at: {args.train_list}'
assert os.path.isfile(args.valid_list), f'Validation list not found at: {args.valid_list}'

# %% [markdown]
# ## 2. 모델
# - 참고문헌\[1]\[2]에 따르면 Xception\[3] 모델이 변조 영상 탐지에 가장 좋은 성능을 보여주어 해당 모델을 기본 모델로 선정
#
# \[1] FaceForensics++: Learning to Detect Manipulated Facial Images, ICCV 2019.
# \[2] A Large-scale Challenging Dataset for DeepFace Forensics, CVPR 2020.
# \[3] Xception: Deep Learning with Depthwise Seperable Convolutions, CVPR 2017.

# %% [markdown]
# ### 3-1 Xception 구현

# %%
"""
Author: Andreas Rössler,
Implemented in https://github.com/ondyari/FaceForensics under MIT license
"""


class SeparableConv2d(nn.Module):
    def __init__(self,in_channels,out_channels,kernel_size=1,stride=1,padding=0,dilation=1,bias=False):
        super(SeparableConv2d,self).__init__()

        self.conv1 = nn.Conv2d(in_channels,in_channels,kernel_size,stride,padding,dilation,groups=in_channels,bias=bias)
        self.pointwise = nn.Conv2d(in_channels,out_channels,1,1,0,1,1,bias=bias)

    def forward(self,x):
        x = self.conv1(x)
        x = self.pointwise(x)
        return x


class Block(nn.Module):
    def __init__(self,in_filters,out_filters,reps,strides=1,start_with_relu=True,grow_first=True):
        super(Block, self).__init__()

        if out_filters != in_filters or strides!=1:
            self.skip = nn.Conv2d(in_filters,out_filters,1,stride=strides, bias=False)
            self.skipbn = nn.BatchNorm2d(out_filters)
        else:
            self.skip=None

        self.relu = nn.ReLU(inplace=True)
        rep=[]

        filters=in_filters
        if grow_first:
            rep.append(self.relu)
            rep.append(SeparableConv2d(in_filters,out_filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(out_filters))
            filters = out_filters

        for i in range(reps-1):
            rep.append(self.relu)
            rep.append(SeparableConv2d(filters,filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(filters))

        if not grow_first:
            rep.append(self.relu)
            rep.append(SeparableConv2d(in_filters,out_filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(out_filters))

        if not start_with_relu:
            rep = rep[1:]
        else:
            rep[0] = nn.ReLU(inplace=False)

        if strides != 1:
            rep.append(nn.MaxPool2d(3,strides,1))
        self.rep = nn.Sequential(*rep)

    def forward(self,inp):
        x = self.rep(inp)

        if self.skip is not None:
            skip = self.skip(inp)
            skip = self.skipbn(skip)
        else:
            skip = inp

        x+=skip
        return x


class Xception(nn.Module):
    def __init__(self, num_classes=1000):
        super(Xception, self).__init__()
        self.num_classes = num_classes

        self.conv1 = nn.Conv2d(3,32,3,2,0,bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.relu = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv2d(32,64,3,bias=False)
        self.bn2 = nn.BatchNorm2d(64)

        self.block1=Block(64,128,2,2,start_with_relu=False,grow_first=True)
        self.block2=Block(128,256,2,2,start_with_relu=True,grow_first=True)
        self.block3=Block(256,728,2,2,start_with_relu=True,grow_first=True)

        self.block4=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block5=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block6=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block7=Block(728,728,3,1,start_with_relu=True,grow_first=True)

        self.block8=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block9=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block10=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block11=Block(728,728,3,1,start_with_relu=True,grow_first=True)

        self.block12=Block(728,1024,2,2,start_with_relu=True,grow_first=False)

        self.conv3 = SeparableConv2d(1024,1536,3,1,1)
        self.bn3 = nn.BatchNorm2d(1536)

        self.conv4 = SeparableConv2d(1536,2048,3,1,1)
        self.bn4 = nn.BatchNorm2d(2048)

        self.fc = nn.Linear(2048, num_classes)

    def features(self, input):
        x = self.conv1(input)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)

        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)
        x = self.block6(x)
        x = self.block7(x)
        x = self.block8(x)
        x = self.block9(x)
        x = self.block10(x)
        x = self.block11(x)
        x = self.block12(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)

        x = self.conv4(x)
        x = self.bn4(x)
        return x

    def logits(self, features):
        x = self.relu(features)

        x = F.adaptive_avg_pool2d(x, (1, 1)) 
        x = x.view(x.size(0), -1)
        x = self.last_linear(x)
        return x

    def forward(self, input):
        x = self.features(input)
        x = self.logits(x)
        return x


## 기존 Xception에 Dropout만 추가
class xception(nn.Module):
    def __init__(self, num_out_classes=2, dropout=0.5):
        super(xception, self).__init__()

        self.model = Xception(num_classes=num_out_classes)
        self.model.last_linear = self.model.fc
        del self.model.fc

        num_ftrs = self.model.last_linear.in_features
        if not dropout:
            self.model.last_linear = nn.Linear(num_ftrs, num_out_classes)
        else:            
            self.model.last_linear = nn.Sequential(
                nn.Dropout(p=dropout),
                nn.Linear(num_ftrs, num_out_classes)
            )

    def forward(self, x):
        x = self.model(x)
        return x

# %% [markdown]
# ### 2-2. Pretrained Weight
# - FaceForensics++ 데이터로 학습된 pre-trained model weight 다운\[4]
#
# \[4]https://github.com/HongguLiu/Deepfake-Detection

# %%
# !wget -O deepfake_c0_xception.pkl --no-check-certificate 'https://docs.google.com/uc?export=download&id=1eHRN117X0loEff7EBk1mGMJeGbGKsd7m'
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'id'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %% [markdown]
# ## 3. 훈련

# %% [markdown]
# ### 3-1 전처리
# - dlib을 이용하여 얼굴만 Cropping하여 학습하였을 때, 0.94점에서 올라가지 못하였음
# - 얼굴 추출없이 CenterCrop하여 학습하였을 때, 가장 좋은 점수 0.97점을 얻음
# - 그 외 설정은 Pre-train에 사용된 설정과 같음

# %%
xception_default = {
    'train': transforms.Compose([transforms.CenterCrop((299, 299)),
                                 transforms.ToTensor(),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.Normalize([0.5]*3, [0.5]*3),
                                 ]),
    'valid': transforms.Compose([transforms.CenterCrop((299, 299)),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.5]*3, [0.5]*3),
                                 ]),
    'test': transforms.Compose([transforms.CenterCrop((299, 299)),
                                transforms.ToTensor(),
                                transforms.Normalize([0.5] * 3, [0.5] * 3),
                                ]),
}

# %% [markdown]
# ### 3-2 Train/Validate/Dataset 함수
# - 홈페이지 제공 함수를 수정하여 사용

# %%
# util

def save_checkpoint(state, is_best, filename='checkpoint.pth.tar'):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, 'model_best.pth.tar')

def adjust_learning_rate(optimizer, epoch, args):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = args.lr * (0.1 ** (epoch // 30))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
# custom dataset

class ImageRecord(object):
    def __init__(self, row):
        self._data = row

    @property
    def path(self):
        return self._data[0]

    @property
    def label(self):
        return int(self._data[1])


class DFDCDatatset(data.Dataset):
    def __init__(self, root_path, list_file, transform=None):
        self.root_path = root_path
        self.list_file = list_file
        self.transform = transform

        self._parse_list()

    def _load_image(self, image_path):
        return Image.open(image_path).convert('RGB')

    def _parse_list(self):
        self.image_list = [ImageRecord(x.strip().split(' ')) for x in open(self.list_file)]

    def __getitem__(self, index):
        record = self.image_list[index]
        image_name = os.path.join(self.root_path, record.path)
        image = self._load_image(image_name)

        if self.transform is not None:
            image = self.transform(image)

        return image, record.label

    def __len__(self):
        return len(self.image_list)

# %%
# train / validate

def train(train_loader, model, criterion, optimizer, epoch):   
    n = 0
    running_loss = 0.0
    running_corrects = 0

    model.train()

    with tqdm.tqdm(train_loader, total=len(train_loader), desc="Train", file=sys.stdout) as iterator:
        for images, target in iterator:
            if args.gpu is not None:
                images = images.cuda(args.gpu, non_blocking=True)
                target = target.cuda(args.gpu, non_blocking=True)

            outputs = model(images)
            _, pred = torch.max(outputs.data, 1)

            loss = criterion(outputs, target)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            n += images.size(0)
            running_loss += loss.item() * images.size(0)
            running_corrects += torch.sum(pred == target.data)

            epoch_loss = running_loss / float(n)
            epoch_acc = running_corrects / float(n)

            log = 'loss - {:.4f}, acc - {:.3f}'.format(epoch_loss, epoch_acc)
            iterator.set_postfix_str(log)

    scheduler.step()


def validate(test_loader, model, criterion):
    n = 0
    running_loss = 0.0
    running_corrects = 0

    model.eval()

    with tqdm.tqdm(valid_loader, total=len(valid_loader), desc="Valid", file=sys.stdout) as iterator:
        for images, target in iterator:
            if args.gpu is not None:
                images = images.cuda(args.gpu, non_blocking=True)
                target = target.cuda(args.gpu, non_blocking=True)

            with torch.no_grad():
                output = model(images)

            loss = criterion(output, target)
            _, pred = torch.max(output.data, 1)

            n += images.size(0)
            running_loss += loss.item() * images.size(0)
            running_corrects += torch.sum(pred == target.data)

            epoch_loss = running_loss / float(n)
            epoch_acc = running_corrects / float(n)

            log = 'loss - {:.4f}, acc - {:.3f}'.format(epoch_loss, epoch_acc)
            iterator.set_postfix_str(log)

    return epoch_acc

# %%
# import gdown

# # 모델을 저장할 디렉토리 생성
# os.makedirs("D:/01.deepfake/models", exist_ok=True)

# # Google Drive에서 파일 다운로드
# url = "https://docs.google.com/uc?export=download&id=1eHRN117X0loEff7EBk1mGMJeGbGKsd7m"
# output = "D:/01.deepfake/models/deepfake_c0_xception.pkl"
# gdown.download(url, output, quiet=False)

# %% [markdown]
# ### 3-3. 훈련
# - 하이퍼파라미터
#   - Batch=32
#   - Adam(lr=0.001)
#   - Epoch=1, 2회 이상시 오버핏 발생
#   - lr scheduler 미사용

# %%
model = xception(num_out_classes=2, dropout=0.5)
print("=> creating model '{}'".format('xception'))
model = model.cuda(args.gpu)

# pretrained weight 파일 경로
pretrained_path = "D:/01.deepfake/models/deepfake_c0_xception.pkl"

# 파일 존재 확인
assert os.path.isfile(pretrained_path), f'Pretrained weight not found at: {pretrained_path}'

# 모델 로드
model.load_state_dict(torch.load(pretrained_path))
print("=> model weight '{}' is loaded".format(pretrained_path))

# loss function과 optimizer 설정
criterion = nn.CrossEntropyLoss().cuda()
optimizer = optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08)
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
# Out:
# => creating model 'xception'
# => model weight 'D:/01.deepfake/models/deepfake_c0_xception.pkl' is loaded
# C:\Users\ksw9066\AppData\Local\Temp\ipykernel_20080\1809400279.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_path))

# %%
train_dataset = DFDCDatatset(args.root,
                             args.train_list,
                             xception_default["train"],
                             )

valid_dataset = DFDCDatatset(args.root,
                             args.valid_list,
                             xception_default["valid"],
                             )

# %%
import json
import cv2
import os
from glob import glob
import random
import shutil

def extract_frames_from_videos():
    # 기본 경로 설정
    video_path = "D:/01.deepfake/dfdc_train_part_0 - 복사본"
    frames_path = "D:/01.deepfake/frames"
    
    # frames 디렉토리 생성
    os.makedirs(frames_path, exist_ok=True)
    
    # metadata.json 파일 읽기
    with open(os.path.join(video_path, "metadata.json"), "r") as f:
        metadata = json.load(f)
    
    print(f"Total videos in metadata: {len(metadata)}")
    
    # 각 비디오에서 프레임 추출
    for video_name, info in metadata.items():
        video_file = os.path.join(video_path, video_name)
        if not os.path.exists(video_file):
            continue
            
        # 레이블에 따른 저장 경로 설정
        label = info['label'].lower()
        save_dir = os.path.join(frames_path, label)
        os.makedirs(save_dir, exist_ok=True)
        
        # 프레임 파일 이름
        frame_name = f"{os.path.splitext(video_name)[0]}.jpg"
        save_path = os.path.join(save_dir, frame_name)
        
        # 이미 프레임이 존재하면 건너뜀
        if os.path.exists(save_path):
            print(f"Skipping already existing frame: {save_path}")
            continue
        
        # 비디오 열기
        cap = cv2.VideoCapture(video_file)
        
        # 중간 프레임 추출
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        middle_frame = total_frames // 2
        
        cap.set(cv2.CAP_PROP_POS_FRAMES, middle_frame)
        ret, frame = cap.read()
        
        if ret:
            # 프레임 저장
            cv2.imwrite(save_path, frame)
            print(f"Saved frame: {save_path}")
        
        cap.release()
    
    return frames_path

def create_train_valid_lists(frames_path, train_ratio=0.8):
    # real과 fake 이미지 경로 수집
    real_images = glob(os.path.join(frames_path, "real", "*.jpg"))
    fake_images = glob(os.path.join(frames_path, "fake", "*.jpg"))
    
    # 각각 섞기
    random.shuffle(real_images)
    random.shuffle(fake_images)
    
    # 8:2로 분할
    real_split = int(len(real_images) * train_ratio)
    fake_split = int(len(fake_images) * train_ratio)
    
    train_images = real_images[:real_split] + fake_images[:fake_split]
    valid_images = real_images[real_split:] + fake_images[fake_split:]
    
    random.shuffle(train_images)
    random.shuffle(valid_images)
    
    # 리스트 파일 생성
    base_path = "D:/01.deepfake/dfdc_train_part_0 - 복사본"
    
    with open(os.path.join(base_path, "train_list_1st.txt"), "w") as f:
        for img_path in train_images:
            label = "0" if "real" in img_path else "1"
            rel_path = os.path.relpath(img_path, base_path)
            f.write(f"{rel_path} {label}\n")
            
    with open(os.path.join(base_path, "test_list_1st.txt"), "w") as f:
        for img_path in valid_images:
            label = "0" if "real" in img_path else "1"
            rel_path = os.path.relpath(img_path, base_path)
            f.write(f"{rel_path} {label}\n")
    
    print(f"Created train list with {len(train_images)} images")
    print(f"Created validation list with {len(valid_images)} images")

# 프레임 추출 및 리스트 생성
print("Extracting frames from videos...")
frames_path = extract_frames_from_videos()

print("\nCreating train/validation lists...")
create_train_valid_lists(frames_path)
# Out:
# Extracting frames from videos...
# Total videos in metadata: 5170
# Skipping already existing frame: D:/01.deepfake/frames\fake\owxbbpjpch.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\vpmyeepbep.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\fzvpbrzssi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\htorvhbcae.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fckxaqjbxk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sphirandia.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vsmadeuczx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ohaqlzfnuv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\komngcqveq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iafvzgpbix.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uaukglhmje.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\syxobtuucp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dtjcyzgdts.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\viuioldtnu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wnaweyzlqh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ejhhdlzpjg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sxyrkshzsg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uvfkppqsjy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kedahvzait.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\idczhqbbqz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\clzkcmoyhb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vpjfmetsvn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\muksyyltmg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ztwlbdwyni.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jaurxwocly.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jkxjvuioek.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\dhjnjkzuhq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\xcruhaccxc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rfpjsloxzg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kmcdjxmnoa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vvwuqslvnq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rpxnyljmsf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\txxungvxms.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\vtunvalyji.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ihnhxathkq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lobxktzhbg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\slhinthqcq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hqzwudvhih.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xpzfhhwkwb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sglzgdcjkb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xxvwbfmgzy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dtmlspmqqp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hsxrmrcaqh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ykbhmueovi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\inzrlbgtul.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xtcbnasaew.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kgfcupxgur.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nkojmntmdg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\btizoxwqwp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zvsivkdkak.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yjllqhbmke.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\qyqufaskjs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ygknkubeyb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wkczijuamz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dolynaukae.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\eisofhptvk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xymeodlrhb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vqwkmjorkj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\rnpefxwptv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gilzdnbpep.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bpguesjrfa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vamicuaopj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jqypqwufdv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\oypqzdrhcr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nglitpseyp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\onknhowfqb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\izjvqhjokl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wirblaouzv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hgjdosshpt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\padqtwbzzo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gxzdueambi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qjvjkojjkl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\oobmorozgk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dsiirbwwyt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\buzdtxdyid.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\aymlynzeni.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gcphojsohr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\scpglaliyh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wwvykizoms.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fswszwicfw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uyhqrokmfe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\imndwwlfui.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rpnetwqgqz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\stgusxhcta.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\oibtsgqujh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iazovjywij.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lxnqzocgaq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\sttnfyptum.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\eurhttghny.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kdiokpezzi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gbgtzspdnv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tyijytqowe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wvjtrmduky.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hqcrauawma.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\chzqptmqxv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kkxgqvpusd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tvjlounpor.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tkcuhfhdzs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sufvvwmbha.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ozeqabydww.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yxirnfyijn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uklvqsnxgv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ngyoubuxyf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wpysxggnok.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ocveomkblt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qjwomijmcb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wpnukldybg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xdbnawbnvf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\drmtvuyoam.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\xugmhbetrw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lblzsydwit.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\euzlhrwolz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yhchnvjcok.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zfkgevlnur.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\uqtqhiqymz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fgbopxbkam.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kkhrtmftlq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hbdvyzpqny.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\khfyqlxazq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pxgzahcusu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cvycgtwfsi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\keuvybqsbr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\skewcclbhg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hjxckindzx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\espkiocpxq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cvdrzlkwdf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uiaubrlxyl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kafmsctues.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\snlyjbnpgw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gkicllwmyb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iimnvjpgoy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zxyvcnkeiz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sfjtewgmuy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\liuujwwgpr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\oejlipxtai.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dabysiasvf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ypufjcamul.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hsvbimzuza.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\skrpivsmry.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gfkdvulbfo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vwbzhldrub.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mynzuyrmdy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mcbubknuyd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\myszscymzv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\epeyujjlhn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xexmngtcha.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\usutboyyqq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vjzhumqpwi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ebzsqgfpgh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rmmcypdfbr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vnnohpqhjq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kanuhxwqaa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cqomufbzpp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\edqhdckynd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ngnoguzzkd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\jawgcggquk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\auquqlmsts.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\embmaestpq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mmhrkzptld.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mxibogtmey.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gmctmgmyob.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\msoqnkucal.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\smxxhrcwlv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yabvnuhvkn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\alhqaurncj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wvuualjyur.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lclrhuuwnj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\myoydssaii.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ssitlrruir.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fuiglusbnl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yiabajckla.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\awigxxbbpb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rxpwfcsqum.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wyctddnyko.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\meehftqexr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pyujkxwaks.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zaendkbrip.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lbuwogzooa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xdqrsjzsul.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pzqxrczvxb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wzrhdvpktx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tamvgvhhbr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ewknjjmzqb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\brpkkgdggv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\yexeazbqig.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\horutnradk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\hivnldfvyl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bqvhlqlrba.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gvlraqlweh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lmpfbmeade.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\duczhwighk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nombfkmhum.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cemftmsxis.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\osmnegfehr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pbvgwcwzkg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gnlvnyrpfq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kfgdvqjuzu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uccwyoqmtq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pkkmysbvfh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mzxtrdcccw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kpdsblcqvg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rlffjkxsqq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\scssmbfchs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cjndhcclqi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\wfzjxzhdkj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\erbfxwbqic.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\drlkcilgmc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xawrxpyoau.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vdnitwfbvr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gqnkarjtmh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gfknvvudwk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gkqitjodaa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wykqjiughm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yimqkeekjm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\apedduehoy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qjsroipniu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dfcoyuhhex.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bmfkkzheii.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\juzjntqofi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ehfmarmsvo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wumkadhelo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nxnelrhins.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xgohnozhqe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cvqyddpcxj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uhakqelqri.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kfhmhoxjtx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\surcmsyrlz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kiswvzlayw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\exseruhiuk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wpvnnqoqvc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nfggixifqp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\lnhkjhyhvw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\coujjnypba.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zepsangjjb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nflbwkeqpz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\poxhzrfhha.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kcidxranvr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jxlhrgwjdt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ybdtkypwez.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nokldtllhe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lbiprboxjx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\queqdqiqwj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fedcdqtboz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ljenlvwnlm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qwvxbksoeo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yncjoacwmk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\prdrkaxeob.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iftluclqfd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tynejafvov.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xnkktewjmu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xcmrhxjhfr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fjrueenjyp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wmooshykkb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\epwesrdmpt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\augwyjvlqa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\efktbhpilh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cxjtjcinqt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\opsjddoxui.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lvuvvfmmli.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ibjomudxdp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tqsratgvwa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kssjbbrmem.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ilflslfgbn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vmdpfyfkwi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xssuxipwtu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kfbdnasciu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dzpokpqpxr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\awfjdqqygu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rdbxcbseek.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kfnrvxndoj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\pqdeutauqc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uwzlafwdra.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hsbljbsgxr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\aaqaifqrwn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ksjpgrujqv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dsvopuhqiz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zovntpfyum.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uaspniazcl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gwzfugbidx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\untxvzuldz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\omrtielsni.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\duciovvndy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\maxybxfgts.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bytfrsxnwi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rmplscucbt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dzlpfpszyv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\xjzkfqddyk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pjqxxtafix.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pmmhsciico.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yihsmubqwx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dwkkqhxclz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hdgfgvcoqk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jstwvimaml.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rfjuhbnlro.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rqlpmeyhqh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pilxtozlrg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uakmltagvm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\snjzgkxvym.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\koxwykmawn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\whpyhuicpe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zrueallpey.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wjypybysuw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\fufcmupzen.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tkyrsegtdw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jqlsethxvz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sakziaduuh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uraibiaste.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\aiuimrebtg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mdihiuwzea.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\idmruoiylw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bykgnyykta.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fybkxkgstv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gwsmeakcic.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\llkhptusjn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dywronddes.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kezvvweubg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mfvqmuulak.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zpilavstvx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yzuestxcbq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mpuugiqewv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cfyayetydv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\frmzkdhkzw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zcnslhnnhl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gtdjfweoyr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gxonqiyzpk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\haxnhfvqvs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rrdamrrple.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gccnvdoknm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qcjwsygnxe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ryccazlbju.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hasjjkoygr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tdontxxzek.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rxicpvwbdn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\oyqgwjdwaj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uotkopqsnc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gtinxlhder.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\umpscxhfsk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\lokzwdldxp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dkojxwpvza.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jgybxxtltz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xykfexpxnv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cxgieqcozm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ntpmamjdyk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xrqhflacsg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ikpyxzpiiv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\scxgpnknil.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\eefzpdrrji.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\hplxtssgnz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yajhwipypq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zqjzmarjbk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xnmnhtwtex.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yqlojrwakg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gfoozygynw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zpbggelffo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ytyptdjoay.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\etdliwticv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zmndlwmybr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\culaevxduf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ddqtkrkmjn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\atrteuctxr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\toinozytsp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sijzcbwppo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gvbcwuyaot.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cythdgxpdi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uqiehguuzl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\gcdtglsoqj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zyjmvauuzw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\npneqyjgiq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\occttwpuuq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mvnahpueuk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\voudmumlov.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xkmpyvtdch.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bbnesewcot.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\biatmogsbv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\huznbaakma.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ojayvjcdna.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hvlqewtbbf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tnougkhbju.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pfvbpqjaxg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jquevmhdvc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dgyeaodnzw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\djgbahezbh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kihrpdtbwy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gfcycflhbo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yuuaxskvqi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cbzxykepbl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rtwlskwxqy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xnztznqlis.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qowkhqmzam.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hpwdlgshqg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jphmkhpoeb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kkemhrscxz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nbypuhsjwp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fsdrwikhge.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jdzgjbqksy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lptoozyjas.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tnwavwcrmn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pjkgenkrgb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jbwtvoixgc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bihlajjbnl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wfgelanyvu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\itfsvvmslp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jjxzidyitl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ytoghswfjl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qfgxitlutn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nyknlonjxq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\swsaoktwgi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dahvuijxob.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tdsndnisso.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vapznfzfle.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uzrbokfzmp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wczbchfnad.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\enqxsifggs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qodykiwotk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uhrofvfghh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\oykagryjjd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iagkfqsiqf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ujsihxqppu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zvuidmemcp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jwkgjrmfxp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lgqlkfrnuc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tbujzmjpsl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dxdzrfikon.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xewwsdhdro.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nadprinqny.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yhoincdvdk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jhetgmikln.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\wclvkepakb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iwtjnrbcbb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cthdrbnhpo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\urvzpbswoh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cqhwesrciw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lzertxjdds.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ealulizawd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gjxfowkaeo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ktrleojxlf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ysqbnccstr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\asdzplbhnm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qrkjzekzkc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\laojqujlsg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\alidfjtwvg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tvakyyfsvb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pzzuimgwei.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\frsjawvaoq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ridrlfphki.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\smxqivzwed.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ufaigyxttb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sgyztejbsh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wugnnrsolg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tjdxwdoumt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vsxuvpwqmm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kqsjsvinkd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zbvlctwcqr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nhsqkozagd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qweikxnvyq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hkvcbcfulf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xtaktzlrme.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sochqsfsow.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\szulggywzw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ldpfwhrhcx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\apzckowxpy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lrpjtzwsdt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lkdqvgrmzh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ptpusmxreb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\eqakbrnwmd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ludeqgyyct.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lncevtcwya.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vopokawkip.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bzvzpwrabw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gpjhljtyoq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tvhjcfnqtg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gmaghrdamw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kujvvxpted.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gohsbddbhu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\omfsuzvgxn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nwtdlrhqtf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xfmcdyaipa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kzezrsewki.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dkenctaoes.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zhkqxjalrq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\enhiqdvfpu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jmcryhnksj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hcanfkwivl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vstmxsekmm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\upmgtackuf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nzeqbdtlla.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zxvgazoudy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hbtcuqhwyy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rptqbxpesg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lmjzfqizks.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wcssbghcpc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lljlzhmrhp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pframtxswx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ttsiapwbgk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kbssbcdcxx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\drooaxkvib.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\rmuxlgsedw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ljkjnwrzxv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bemkbovwsz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ygsffqgqcg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pvevprrtnu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\calhtslbzf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pftrwqispi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ccrrlidqnp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qjeidqbpgj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kiyuduxzuc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\twxfrcqxfu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zkarzsylvk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yrivmbpotx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\lnjkpdviqb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\faktmhmtpb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\hicjuubiau.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ntpvqwgmqe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mcllgspbtl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\usqqvxcjmg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rtpbawlmxr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mqmgqlbzct.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tafsqvrhuv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vtlxnjhdvs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xjfvhfyunl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qlueobbhbc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zpllznxapc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gyrdgpiygb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\birmbtezni.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\twntheorhj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ruvadafqri.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mordcwbchi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uripyyofxy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\fsaronfupy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gozbrlxguv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yptchajnvb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\prhmixykhr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uzcezdepho.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mrovsdlffg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uaqxrykyxq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bwjqcwhpfr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\toewhlbcgt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jhczqfefgw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ecnmwevrxo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ccjiwxnihq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dcwnkxrsgg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pcwavxhyrj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ookwdfuxzy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iorrnxiyyo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nzuvtbkmye.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\prmwoaeeng.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dbgztzhbhb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kmhiqddyhh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hitfycdavv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gldlvkplzy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nrrselamng.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qzchhaoptt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yhbpxjcglo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\utqhlximwa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fdzrcjpewd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gtfwzfrxml.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kquembvlju.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gqnaxievjx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lhipivaobq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tnrmnayszi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\goyrhrvden.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\acryukkddn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kpmieleslf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\frqhofmoob.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\apmzxocjio.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wdcrhqtjhf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wmoigsbnem.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zzlsynxeff.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\ucthmsajay.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lslmnvlhhe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tjywwgftmv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cqtxrekabh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yivspcmkbk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\fopjiyxiqd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wsakxxhoae.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xfgdnsbnto.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\brtujopkby.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lydmxmeegq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mphsgertmm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\moerpiyczb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zumqskdmht.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yugbeaqhlf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tdspbqidzz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pgehjsocyc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jinomojicv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jtrbieopvk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xzqgptotdo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jdfaxqtpjk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zqodmfrtbs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\acagallncj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lsadkstabm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wyqdbqmbjk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\jytrvwlewz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gnslnjrgnx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yllztsrwjw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zybunacsgi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mywukrvlwr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\safmejeucy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\aegvtnwqoe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wutqmgtqac.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cqbhgsmffd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qrgrezupjj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yotyalfqqv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cwvpcctjgs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\axfhbpkdlc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uplcuyuvgf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kdzirwrnyk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sqbyylskze.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rxjcinqyqd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\itwvssoevj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\atzwrsivnb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\real\rmufsuogzn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wfugqfvekh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ndonldsrsr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vjfjniqnxx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uiqhpnzcmp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nsifmpyfnq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mfkzoapcqm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wsgmrrwxwt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wlyfcpecea.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jdkvgcjxje.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vzockawbyi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dlfuxshert.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pceaundfcd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gudedkpnie.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\elxflqcpgp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yzrngdribf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xlmduthjih.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iffvaaswwj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\adftmlvzfs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mmuolksboc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mrhajrsgxh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rxwqoruisz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bzyawroeif.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\flilazlokf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bzxauvpscl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vtzlfurays.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\inwiunnxmr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tufacqdefx.jpg
# ...
# Skipping already existing frame: D:/01.deepfake/frames\fake\ogaxeeegzg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cktnvixgub.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ghncfauixn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jfmmvfpudw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kpktmafsnl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xomjpqxtdh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ldmoodikzl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\clgpmpxpxa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\otilzpjrfc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\niypamicvn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wbwipxamgj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mapkjstmip.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wzsfoifswy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dxzscteuyd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fyewovfowx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ylqucqmtbi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zyufpqvpyu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hdmhhcixqb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ptbfnkajyi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ftrvqvielv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fhlxhkrpyt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ranvoqkzwn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pswdsdsfha.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lcloalkyrx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jaogotncwj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jfgidfrxqn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\araoplrpeb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\chihfjebdp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\psckptrrys.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ybmyhjyabe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\phoxxwoozc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rrlgynofwd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qpvgdzncxe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nqotvzfcck.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xpedyhitul.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vlmllzbcbe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sropxiectt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wcvsqnplsk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jtuiddncpo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\eywdmustbb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ipisbnwavn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\binribybof.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mskuywhlfh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cjbejshqep.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xxigldllip.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vzzkunmkkl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zltamubaab.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mshernruud.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\woxyzsfoyv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hxdggdclkc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fqgypsunzr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\roltkgcnoc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\fazxlgrnot.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qqkyznondw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bppvyenwri.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\axyczuqmyl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yirhsptlko.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nmmizonqhs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ddtgcdxlfj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rysmxgsgly.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bdeouczrwb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mtzvnmxgqj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ijxjjxtrsi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\knceeulwam.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lthliysdpo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lptongiurm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xvgkojxxwd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rvyvuuvdxs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xswdwufkyy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\foftbpkdev.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ohxzmopbvc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jnqmcyshrf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pcvpkdmppy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wufsogqfhx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mxpqyayjka.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cebcmahlap.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hvmzimtrdq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\npsotexafg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tbtbhuncfm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bjorshdgjo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\snhqpfqbsf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nxabngwifq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\syomlwoate.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wtooqmfqsq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jsysgmycsx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\srdrsrbfzj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xiutydegfu.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\meksaaboua.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\enerzluejw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lurgyrniwf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sxjybmxvms.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dsbrnbihpn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\npjwiaxcjd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\getuajcsmb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yayiggnpuw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lwiziramni.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\houzrrfbqg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xcrfebhpzf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zktfvbaupk.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\niptrdsfjq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vmigrsncac.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\idfpkfirul.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\aahsnkchkz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jowxvukjyo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rcgccchtvn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xyrslykzlj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yhoylflxjo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wmltghyhfh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zsmtlfucab.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\aoayayeqji.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yyacdikwrg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\qilkmlkovm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kuryxaqwqz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tlwffdhger.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ctjewcqxee.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jzimocxipm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rcejkynepf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nimjvlvgfj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uyextxwokc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\upfgdyshre.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\obwygkicpv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iaoudvakbo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lbywhswpgc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mgiofhkmqe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bstbbiefie.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tzegdvincl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\olxuxttfce.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\olqctxmttw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\imuifxhtpx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xvpyayjsmf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xlqdwwxxzb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jlluezfnyr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zewluzlkbe.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zzgtjnoyoo.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ydnvgacdnv.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ouopeunsmf.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nioeronoih.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rytusspynn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xzbkneczno.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dbyfoksnlh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wyfckvawpg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xwpcgrdpqy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xsqazrqgah.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\czifmcopho.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bcvheslzrq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cshlbvfpzi.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\imdmhwkkni.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rqgdchivrl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\esmqxszybs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ammowfdpae.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bbaeewtqei.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zzsvsjkcva.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\yxadevzohx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tpxpejlgev.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mqyqjzccao.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xwotyajtkq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gnbaqomlin.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wgsenzwsjp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pruvhwligx.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\enwdngjood.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jsksmezfth.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mldkxuuwze.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\wvbzxaspaa.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\woahqydkcl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\djzyraaict.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mbqpmbgxve.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kowgqrymzs.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ohtgaalrue.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tunylyceda.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nvxgxrvjww.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\rucctscaqp.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cbtcwfzudb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jzzcskarto.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nraqgmsnmm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\tomfehexjw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\oqwpakepin.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ehkjdctavq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\pfoiiepvxb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mxwqmxncer.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\kcjvhgvhpt.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jlmmslbing.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hqldzgqqpg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dqqwmmwlbg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sevpubemdc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\iuvfvfzxeh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jhvvkiwfwq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\snhsvdcgpm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sforadgblh.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zbpltusqqm.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\hqczhhssie.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nutazlhrji.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\uzcfbthcin.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\krbdxferiy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\cwhoszpfek.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lkqotnclpd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\nwwvbgkbgc.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\dohidzgzqj.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\krbdlemuzz.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ibvomadohg.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\lmqpkvjpru.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\vqqvveifjn.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\jikxnnhscb.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\mbqctmgdhl.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ybnjvhunta.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\ocguwrotdy.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\bhidtfximd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\gxwmwjmyxr.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\egxdgjsilw.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\zsormhyuwd.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\xhdbbnhzbq.jpg
# Skipping already existing frame: D:/01.deepfake/frames\fake\sdibedfnep.jpg
#
# Creating train/validation lists...
# Created train list with 4135 images
# Created validation list with 1035 images

# %%
import torch
import torch.utils.data as data
from torchvision import transforms
import os
from PIL import Image

# args 수정
args = easydict.EasyDict({
    "gpu": 0,
    "num_workers": 4,  # 시스템 사양에 맞게 조정

    # 경로 수정
    "root": "D:/01.deepfake/dfdc_train_part_0 - 복사본",
    "train_list": "D:/01.deepfake/dfdc_train_part_0 - 복사본/train_list_1st.txt",
    "valid_list": "D:/01.deepfake/dfdc_train_part_0 - 복사본/test_list_1st.txt",

    "learning_rate": 0.001,
    "num_epochs": 1,
    "batch_size": 16,  # GPU 메모리에 맞게 조정

    "save_fn": "D:/01.deepfake/models/deepfake_c0_xception_tuned.pth.tar",
})

# 데이터셋 생성
train_dataset = DFDCDatatset(
    args.root,
    args.train_list,
    xception_default["train"]
)

valid_dataset = DFDCDatatset(
    args.root,
    args.valid_list,
    xception_default["valid"]
)

print(f"Training dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(valid_dataset)}")

# DataLoader 생성
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=args.batch_size,
    shuffle=True,
    num_workers=args.num_workers,
    pin_memory=True,
)

valid_loader = torch.utils.data.DataLoader(
    valid_dataset,
    batch_size=args.batch_size,
    shuffle=False,
    num_workers=args.num_workers,
    pin_memory=False,
)
# Out:
# Training dataset size: 4135
# Validation dataset size: 1035

# %%
# # 1. DataLoader 설정 수정
# train_loader = torch.utils.data.DataLoader(
#     train_dataset,
#     batch_size=args.batch_size,
#     shuffle=True,
#     num_workers=0,  # worker 수를 0으로 설정하여 디버깅
#     pin_memory=True,
# )

# valid_loader = torch.utils.data.DataLoader(
#     valid_dataset,
#     batch_size=args.batch_size,
#     shuffle=False,
#     num_workers=0,  # worker 수를 0으로 설정하여 디버깅
#     pin_memory=False,
# )

# # 2. 학습 함수에 예외 처리 추가
# def train(train_loader, model, criterion, optimizer, epoch):   
#     try:
#         n = 0
#         running_loss = 0.0
#         running_corrects = 0

#         model.train()

#         with tqdm.tqdm(train_loader, total=len(train_loader), desc="Train", file=sys.stdout) as iterator:
#             for images, target in iterator:
#                 try:
#                     if args.gpu is not None:
#                         images = images.cuda(args.gpu, non_blocking=True)
#                         target = target.cuda(args.gpu, non_blocking=True)

#                     outputs = model(images)
#                     _, pred = torch.max(outputs.data, 1)

#                     loss = criterion(outputs, target)

#                     optimizer.zero_grad()
#                     loss.backward()
#                     optimizer.step()

#                     n += images.size(0)
#                     running_loss += loss.item() * images.size(0)
#                     running_corrects += torch.sum(pred == target.data)

#                     epoch_loss = running_loss / float(n)
#                     epoch_acc = running_corrects / float(n)

#                     log = 'loss - {:.4f}, acc - {:.3f}'.format(epoch_loss, epoch_acc)
#                     iterator.set_postfix_str(log)
                
#                 except Exception as e:
#                     print(f"Error in training batch: {str(e)}")
#                     continue

#         scheduler.step()
    
#     except Exception as e:
#         print(f"Error in training: {str(e)}")
#         raise e

# # 3. 실행
# print('-' * 50)
# print('Epoch {}/{}'.format(1, args.num_epochs))

# try:
#     train(train_loader, model, criterion, optimizer, 0)
#     acc = validate(valid_loader, model, criterion)

#     save_checkpoint(state={'epoch': args.num_epochs + 1,
#                           'state_dict': model.state_dict(),
#                           'best_acc1': acc,
#                           'optimizer': optimizer.state_dict(),},
#                    is_best=False,
#                    filename=args.save_fn,
#                    )
# except Exception as e:
#     print(f"Training failed: {str(e)}")

# %%
# # 디바이스 설정
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = model.to(device)  # 모델을 디바이스로 이동

# for epoch in range(args.num_epochs):
#     model.train()
#     train_loss = 0
#     for inputs, labels in train_loader:  # 튜플 언패킹
#         # 데이터를 디바이스로 이동
#         inputs = inputs.to(device)
#         labels = labels.to(device)

#         # Forward, backward, optimize
#         optimizer.zero_grad()
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()
#         train_loss += loss.item()

#     # Validation 루프
#     model.eval()
#     valid_loss = 0
#     correct = 0
#     total = 0
#     with torch.no_grad():
#         for inputs, labels in valid_loader:  # 튜플 언패킹
#             # 데이터를 디바이스로 이동
#             inputs = inputs.to(device)
#             labels = labels.to(device)

#             outputs = model(inputs)
#             loss = criterion(outputs, labels)
#             valid_loss += loss.item()
            
#             # Accuracy 계산
#             _, predicted = torch.max(outputs, 1)
#             correct += (predicted == labels).sum().item()
#             total += labels.size(0)

#     valid_accuracy = correct / total  # Validation accuracy 계산

#     print(f"Epoch {epoch + 1}/{args.num_epochs} - Train Loss: {train_loss:.4f}, "
#           f"Valid Loss: {valid_loss:.4f}, Valid Accuracy: {valid_accuracy:.4f}")

#     # 가장 좋은 모델만 저장
#     best_metric = save_best_model(model, optimizer, epoch, save_path, best_metric, valid_accuracy)

# %%
# # 1. DataLoader 설정
# train_loader = torch.utils.data.DataLoader(
#     train_dataset,
#     batch_size=args.batch_size,
#     shuffle=True,
#     num_workers=0,  # worker 수를 0으로 설정하여 디버깅
#     pin_memory=True,
# )

# valid_loader = torch.utils.data.DataLoader(
#     valid_dataset,
#     batch_size=args.batch_size,
#     shuffle=False,
#     num_workers=0,  # worker 수를 0으로 설정하여 디버깅
#     pin_memory=False,
# )
# args = easydict.EasyDict({
#     "batch_size": 32,
#     "num_epochs": 10,
#     "gpu": 0,
#     "save_dir": "./checkpoints"  # 모델 저장 경로 설정
# })

# # 2. 학습 함수 수정
# def train(train_loader, model, criterion, optimizer, epoch):   
#     try:
#         n = 0
#         running_loss = 0.0
#         running_corrects = 0

#         model.train()

#         with tqdm.tqdm(train_loader, total=len(train_loader), desc=f"Train Epoch {epoch}", file=sys.stdout) as iterator:
#             for images, target in iterator:
#                 try:
#                     if args.gpu is not None:
#                         images = images.cuda(args.gpu, non_blocking=True)
#                         target = target.cuda(args.gpu, non_blocking=True)

#                     outputs = model(images)
#                     _, pred = torch.max(outputs.data, 1)

#                     loss = criterion(outputs, target)

#                     optimizer.zero_grad()
#                     loss.backward()
#                     optimizer.step()

#                     n += images.size(0)
#                     running_loss += loss.item() * images.size(0)
#                     running_corrects += torch.sum(pred == target.data)

#                     epoch_loss = running_loss / float(n)
#                     epoch_acc = running_corrects / float(n)

#                     log = 'loss - {:.4f}, acc - {:.3f}'.format(epoch_loss, epoch_acc)
#                     iterator.set_postfix_str(log)
                
#                 except Exception as e:
#                     print(f"Error in training batch: {str(e)}")
#                     continue

#         scheduler.step()
    
#     except Exception as e:
#         print(f"Error in training: {str(e)}")
#         raise e

# # 3. 검증 함수 (이미 존재한다고 가정, 필요시 추가 작성)
# def validate(valid_loader, model, criterion):
#     model.eval()
#     running_loss = 0.0
#     running_corrects = 0
#     n = 0

#     with torch.no_grad():
#         with tqdm.tqdm(valid_loader, total=len(valid_loader), desc="Validate", file=sys.stdout) as iterator:
#             for images, target in iterator:
#                 if args.gpu is not None:
#                     images = images.cuda(args.gpu, non_blocking=True)
#                     target = target.cuda(args.gpu, non_blocking=True)

#                 outputs = model(images)
#                 _, pred = torch.max(outputs.data, 1)
#                 loss = criterion(outputs, target)

#                 n += images.size(0)
#                 running_loss += loss.item() * images.size(0)
#                 running_corrects += torch.sum(pred == target.data)

#     val_loss = running_loss / float(n)
#     val_acc = running_corrects / float(n)
#     return val_loss, val_acc

# # 4. 실행 (Best 모델 저장 로직 포함)
# best_accuracy = 0.0  # 최고 정확도 초기화
# save_dir = args.save_dir  # 모델 저장 경로

# print('-' * 50)
# for epoch in range(args.num_epochs):
#     print(f"Epoch {epoch + 1}/{args.num_epochs}")
#     try:
#         # 학습
#         train(train_loader, model, criterion, optimizer, epoch)
        
#         # 검증
#         val_loss, val_acc = validate(valid_loader, model, criterion)
#         print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        
#         # 베스트 모델 저장
#         if val_acc > best_accuracy:
#             best_accuracy = val_acc
#             save_path = f"{save_dir}/best_model_epoch_{epoch + 1}.pth"
#             torch.save({
#                 'epoch': epoch + 1,
#                 'model_state_dict': model.state_dict(),
#                 'optimizer_state_dict': optimizer.state_dict(),
#                 'accuracy': best_accuracy,
#             }, save_path)
#             print(f"New best model saved at epoch {epoch + 1} with accuracy: {best_accuracy:.4f}")

#     except Exception as e:
#         print(f"Training failed at epoch {epoch + 1}: {str(e)}")

# %%
from torch.utils.tensorboard import SummaryWriter
import torch.utils.data
import tqdm
import sys
import easydict

# 1. DataLoader 설정 (기존과 동일)
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=args.batch_size,
    shuffle=True,
    num_workers=0,
    pin_memory=True,
)

valid_loader = torch.utils.data.DataLoader(
    valid_dataset,
    batch_size=args.batch_size,
    shuffle=False,
    num_workers=0,
    pin_memory=False,
)

# args에 tensorboard 로그 디렉토리 추가
args = easydict.EasyDict({
    "batch_size": 32,
    "num_epochs": 30,
    "gpu": 0,
    "save_dir": "./checkpoints",
    "log_dir": "./runs"  # tensorboard 로그 저장 경로
})

# 2. 학습 함수 수정 (TensorBoard 추가)
def train(train_loader, model, criterion, optimizer, epoch, writer):   
    try:
        n = 0
        running_loss = 0.0
        running_corrects = 0

        model.train()

        with tqdm.tqdm(train_loader, total=len(train_loader), desc=f"Train Epoch {epoch}", file=sys.stdout) as iterator:
            for i, (images, target) in enumerate(iterator):
                try:
                    if args.gpu is not None:
                        images = images.cuda(args.gpu, non_blocking=True)
                        target = target.cuda(args.gpu, non_blocking=True)

                    outputs = model(images)
                    _, pred = torch.max(outputs.data, 1)

                    loss = criterion(outputs, target)

                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                    n += images.size(0)
                    running_loss += loss.item() * images.size(0)
                    running_corrects += torch.sum(pred == target.data)

                    epoch_loss = running_loss / float(n)
                    epoch_acc = running_corrects.float() / float(n)

                    # TensorBoard에 배치별 손실과 정확도 기록
                    step = epoch * len(train_loader) + i
                    writer.add_scalar('Training/Batch Loss', loss.item(), step)
                    writer.add_scalar('Training/Batch Accuracy', torch.sum(pred == target.data).float() / images.size(0), step)

                    log = 'loss - {:.4f}, acc - {:.3f}'.format(epoch_loss, epoch_acc)
                    iterator.set_postfix_str(log)
                
                except Exception as e:
                    print(f"Error in training batch: {str(e)}")
                    continue

        # TensorBoard에 에폭별 평균 손실과 정확도 기록
        writer.add_scalar('Training/Epoch Loss', epoch_loss, epoch)
        writer.add_scalar('Training/Epoch Accuracy', epoch_acc, epoch)
        writer.add_scalar('Training/Learning Rate', optimizer.param_groups[0]['lr'], epoch)

        scheduler.step()
    
    except Exception as e:
        print(f"Error in training: {str(e)}")
        raise e

# 3. 검증 함수 수정 (TensorBoard 추가)
def validate(valid_loader, model, criterion, epoch, writer):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    n = 0

    with torch.no_grad():
        with tqdm.tqdm(valid_loader, total=len(valid_loader), desc="Validate", file=sys.stdout) as iterator:
            for images, target in iterator:
                if args.gpu is not None:
                    images = images.cuda(args.gpu, non_blocking=True)
                    target = target.cuda(args.gpu, non_blocking=True)

                outputs = model(images)
                _, pred = torch.max(outputs.data, 1)
                loss = criterion(outputs, target)

                n += images.size(0)
                running_loss += loss.item() * images.size(0)
                running_corrects += torch.sum(pred == target.data)

    val_loss = running_loss / float(n)
    val_acc = running_corrects.float() / float(n)

    # TensorBoard에 검증 결과 기록
    writer.add_scalar('Validation/Loss', val_loss, epoch)
    writer.add_scalar('Validation/Accuracy', val_acc, epoch)

    return val_loss, val_acc

# 4. 실행 (TensorBoard 설정 추가)
best_accuracy = 0.0
save_dir = args.save_dir

# TensorBoard writer 초기화
writer = SummaryWriter(args.log_dir)

# 모델 구조를 TensorBoard에 기록 (선택사항)
dummy_input = torch.rand(1, 3, 224, 224).cuda(args.gpu)  # 입력 크기에 맞게 수정
writer.add_graph(model, dummy_input)

print('-' * 50)
for epoch in range(args.num_epochs):
    print(f"Epoch {epoch + 1}/{args.num_epochs}")
    try:
        # 학습
        train(train_loader, model, criterion, optimizer, epoch, writer)
        
        # 검증
        val_loss, val_acc = validate(valid_loader, model, criterion, epoch, writer)
        print(f"Validation Loss: {val_loss:.4f}, Accuracy: {val_acc:.4f}")
        
        # 베스트 모델 저장
        if val_acc > best_accuracy:
            best_accuracy = val_acc
            save_path = f"{save_dir}/best_model_epoch_{epoch + 1}.pth"
            torch.save({
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': best_accuracy,
            }, save_path)
            print(f"New best model saved at epoch {epoch + 1} with accuracy: {best_accuracy:.4f}")

    except Exception as e:
        print(f"Training failed at epoch {epoch + 1}: {str(e)}")

# 학습 완료 후 writer 종료
writer.close()
# Out:
# --------------------------------------------------
# Epoch 1/30
# Train Epoch 0: 100%|██████████| 259/259 [01:59<00:00,  2.17it/s, loss - 0.6566, acc - 0.641]
# Validate: 100%|██████████| 65/65 [00:22<00:00,  2.90it/s]
# Validation Loss: 0.6456, Accuracy: 0.6406
# New best model saved at epoch 1 with accuracy: 0.6406
# Epoch 2/30
# Train Epoch 1: 100%|██████████| 259/259 [01:59<00:00,  2.18it/s, loss - 0.5048, acc - 0.783]
# Validate: 100%|██████████| 65/65 [00:22<00:00,  2.91it/s]
# Validation Loss: 0.4934, Accuracy: 0.8386
# New best model saved at epoch 2 with accuracy: 0.8386
# Epoch 3/30
# Train Epoch 2: 100%|██████████| 259/259 [02:00<00:00,  2.14it/s, loss - 0.3853, acc - 0.842]
# Validate: 100%|██████████| 65/65 [00:23<00:00,  2.82it/s]
# Validation Loss: 0.3425, Accuracy: 0.8937
# New best model saved at epoch 3 with accuracy: 0.8937
# Epoch 4/30
# Train Epoch 3: 100%|██████████| 259/259 [02:06<00:00,  2.04it/s, loss - 0.3249, acc - 0.882]
# Validate: 100%|██████████| 65/65 [00:24<00:00,  2.66it/s]
# Validation Loss: 0.2925, Accuracy: 0.8918
# Epoch 5/30
# Train Epoch 4: 100%|██████████| 259/259 [02:07<00:00,  2.03it/s, loss - 0.3078, acc - 0.887]
# Validate: 100%|██████████| 65/65 [00:22<00:00,  2.88it/s]
# Validation Loss: 0.3064, Accuracy: 0.8734
# Epoch 6/30
# Train Epoch 5: 100%|██████████| 259/259 [02:00<00:00,  2.15it/s, loss - 0.2477, acc - 0.913]
# Validate: 100%|██████████| 65/65 [00:22<00:00,  2.89it/s]
# Validation Loss: 0.2348, Accuracy: 0.9256
# New best model saved at epoch 6 with accuracy: 0.9256
# Epoch 7/30
# Train Epoch 6: 100%|██████████| 259/259 [01:45<00:00,  2.45it/s, loss - 0.2420, acc - 0.916]
# Validate: 100%|██████████| 65/65 [00:22<00:00,  2.88it/s]
# Validation Loss: 0.2432, Accuracy: 0.9256
# Epoch 8/30
# Train Epoch 7: 100%|██████████| 259/259 [01:40<00:00,  2.59it/s, loss - 0.2304, acc - 0.922]
# Validate: 100%|██████████| 65/65 [00:22<00:00,  2.89it/s]
# Validation Loss: 0.2220, Accuracy: 0.9256
# Epoch 9/30
# Train Epoch 8:  80%|███████▉  | 206/259 [01:19<00:20,  2.53it/s, loss - 0.2395, acc - 0.916]

# %% [markdown]
# ## infer.ipynb
# 1. 기본 설정
# 2. Xception 모델
# 3. Inference 및 제출 양식 생성

# %% [markdown]
# ## 1. 기본 설정

# %%
import os
import glob
import easydict
import tqdm
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision import transforms

# %%
args = easydict.EasyDict({    
    "gpu": 0,
    
    # 테스트 데이터 경로 수정
    "root_test": "D:/01.deepfake/test_videos",
    # 결과 파일 저장 경로 수정
    "source_file": "D:/01.deepfake/test_submission.csv",
    # 학습된 모델 파일 경로
    "save_fn": "D:/01.deepfake/models/deepfake_c0_xception_tuned.pth.tar",
})

# 모델 파일 존재 확인
assert os.path.isfile(args.save_fn), f'Model file not found at: {args.save_fn}'

# 테스트 데이터 디렉토리 존재 확인
assert os.path.isdir(args.root_test), f'Test directory not found at: {args.root_test}'

# 결과 파일 저장 디렉토리 생성
os.makedirs(os.path.dirname(args.source_file), exist_ok=True)

# %% [markdown]
# ## 2. 모델

# %%
"""
Author: Andreas Rössler,
Implemented in https://github.com/ondyari/FaceForensics under MIT license
"""

class SeparableConv2d(nn.Module):
    def __init__(self,in_channels,out_channels,kernel_size=1,stride=1,padding=0,dilation=1,bias=False):
        super(SeparableConv2d,self).__init__()

        self.conv1 = nn.Conv2d(in_channels,in_channels,kernel_size,stride,padding,dilation,groups=in_channels,bias=bias)
        self.pointwise = nn.Conv2d(in_channels,out_channels,1,1,0,1,1,bias=bias)

    def forward(self,x):
        x = self.conv1(x)
        x = self.pointwise(x)
        return x


class Block(nn.Module):
    def __init__(self,in_filters,out_filters,reps,strides=1,start_with_relu=True,grow_first=True):
        super(Block, self).__init__()

        if out_filters != in_filters or strides!=1:
            self.skip = nn.Conv2d(in_filters,out_filters,1,stride=strides, bias=False)
            self.skipbn = nn.BatchNorm2d(out_filters)
        else:
            self.skip=None

        self.relu = nn.ReLU(inplace=True)
        rep=[]

        filters=in_filters
        if grow_first:
            rep.append(self.relu)
            rep.append(SeparableConv2d(in_filters,out_filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(out_filters))
            filters = out_filters

        for i in range(reps-1):
            rep.append(self.relu)
            rep.append(SeparableConv2d(filters,filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(filters))

        if not grow_first:
            rep.append(self.relu)
            rep.append(SeparableConv2d(in_filters,out_filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(out_filters))

        if not start_with_relu:
            rep = rep[1:]
        else:
            rep[0] = nn.ReLU(inplace=False)

        if strides != 1:
            rep.append(nn.MaxPool2d(3,strides,1))
        self.rep = nn.Sequential(*rep)

    def forward(self,inp):
        x = self.rep(inp)

        if self.skip is not None:
            skip = self.skip(inp)
            skip = self.skipbn(skip)
        else:
            skip = inp

        x+=skip
        return x


class Xception(nn.Module):
    def __init__(self, num_classes=1000):
        super(Xception, self).__init__()
        self.num_classes = num_classes

        self.conv1 = nn.Conv2d(3,32,3,2,0,bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.relu = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv2d(32,64,3,bias=False)
        self.bn2 = nn.BatchNorm2d(64)

        self.block1=Block(64,128,2,2,start_with_relu=False,grow_first=True)
        self.block2=Block(128,256,2,2,start_with_relu=True,grow_first=True)
        self.block3=Block(256,728,2,2,start_with_relu=True,grow_first=True)

        self.block4=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block5=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block6=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block7=Block(728,728,3,1,start_with_relu=True,grow_first=True)

        self.block8=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block9=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block10=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block11=Block(728,728,3,1,start_with_relu=True,grow_first=True)

        self.block12=Block(728,1024,2,2,start_with_relu=True,grow_first=False)

        self.conv3 = SeparableConv2d(1024,1536,3,1,1)
        self.bn3 = nn.BatchNorm2d(1536)

        self.conv4 = SeparableConv2d(1536,2048,3,1,1)
        self.bn4 = nn.BatchNorm2d(2048)

        self.fc = nn.Linear(2048, num_classes)

    def features(self, input):
        x = self.conv1(input)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)

        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)
        x = self.block6(x)
        x = self.block7(x)
        x = self.block8(x)
        x = self.block9(x)
        x = self.block10(x)
        x = self.block11(x)
        x = self.block12(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)

        x = self.conv4(x)
        x = self.bn4(x)
        return x

    def logits(self, features):
        x = self.relu(features)

        x = F.adaptive_avg_pool2d(x, (1, 1)) 
        x = x.view(x.size(0), -1)
        x = self.last_linear(x)
        return x

    def forward(self, input):
        x = self.features(input)
        x = self.logits(x)
        return x

## 기존 Xception에 Dropout만 추가
class xception(nn.Module):
    def __init__(self, num_out_classes=2, dropout=0.5):
        super(xception, self).__init__()

        self.model = Xception(num_classes=num_out_classes)
        self.model.last_linear = self.model.fc
        del self.model.fc

        num_ftrs = self.model.last_linear.in_features
        if not dropout:
            self.model.last_linear = nn.Linear(num_ftrs, num_out_classes)
        else:            
            self.model.last_linear = nn.Sequential(
                nn.Dropout(p=dropout),
                nn.Linear(num_ftrs, num_out_classes)
            )

    def forward(self, x):
        x = self.model(x)
        return x

# %%
xception_default = {
    'train': transforms.Compose([transforms.CenterCrop((299, 299)),
                                 transforms.ToTensor(),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.Normalize([0.5]*3, [0.5]*3),
                                 ]),
    'valid': transforms.Compose([transforms.CenterCrop((299, 299)),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.5]*3, [0.5]*3),
                                 ]),
    'test': transforms.Compose([transforms.CenterCrop((299, 299)),
                                transforms.ToTensor(),
                                transforms.Normalize([0.5] * 3, [0.5] * 3),
                                ]),
}

# %%
transform = xception_default['test']

# %% [markdown]
# ## 2. Inference 및 제출 양식 생성

# %%
import os
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from PIL import Image
import cv2
from tqdm import tqdm
import numpy as np
from easydict import EasyDict

def get_default_args():
    """기본 설정값들을 반환하는 함수"""
    args = EasyDict()
    
    # GPU 설정
    args.gpu = 0
    
    # 경로 설정
    args.root_test = "D:/01.deepfake/test_videos"
    args.source_file = "D:/01.deepfake/test_submission.csv"
    args.save_dir = 'D:/01.deepfake/checkpoints'
    
    # 모델 설정
    args.num_classes = 2
    args.dropout = 0.5
    
    return args

def extract_frames(video_path, frames_dir):
    """비디오에서 중간 프레임을 추출하는 함수"""
    video_name = os.path.basename(video_path)
    frame_name = os.path.splitext(video_name)[0] + ".jpg"
    frame_path = os.path.join(frames_dir, frame_name)
    
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    middle_frame = total_frames // 2
    
    cap.set(cv2.CAP_PROP_POS_FRAMES, middle_frame)
    ret, frame = cap.read()
    
    if ret:
        cv2.imwrite(frame_path, frame)
        cap.release()
        return frame_path
    
    cap.release()
    return None

def load_best_model(model, checkpoint_dir):
    """저장된 가장 최근의 best 모델을 불러오는 함수"""
    # best_model이 포함된 모든 pth 파일 찾기
    model_files = glob.glob(os.path.join(checkpoint_dir, 'best_model_epoch_*.pth'))
    
    if not model_files:
        raise FileNotFoundError(f"No best model found in {checkpoint_dir}")
    
    # 파일의 수정 시간을 기준으로 정렬하여 가장 최근 파일 선택
    latest_model_path = max(model_files, key=os.path.getctime)
    
    # 모델 불러오기
    checkpoint = torch.load(latest_model_path)
    model.load_state_dict(checkpoint['model_state_dict'])  # 키 이름 수정
    
    print(f"Loaded latest best model from {os.path.basename(latest_model_path)}")
    print(f"Epoch: {checkpoint['epoch']}, Accuracy: {checkpoint['accuracy']:.4f}")
    
    return model

def inference(args, model, transform):
    """추론을 수행하는 함수"""
    # 디바이스 설정
    device = torch.device(f"cuda:{args.gpu}" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()
    
    # Softmax 레이어 설정
    softmax = nn.Softmax(dim=1)
    
    # 테스트 비디오 목록 가져오기
    test_videos = glob.glob(os.path.join(args.root_test, "*.mp4"))
    print(f"Found {len(test_videos)} test videos")
    
    # 프레임 저장 디렉토리 생성
    frames_dir = os.path.join(args.root_test, "frames")
    os.makedirs(frames_dir, exist_ok=True)
    
    # 결과 파일 생성
    os.makedirs(os.path.dirname(args.source_file), exist_ok=True)
    
    predictions = []
    with torch.no_grad():
        for video_path in tqdm(test_videos, desc="Processing videos"):
            try:
                # 프레임 추출
                frame_path = extract_frames(video_path, frames_dir)
                if frame_path is None:
                    print(f"Failed to extract frame from {video_path}")
                    continue
                
                # 이미지 전처리
                image = Image.open(frame_path)
                image_tensor = transform(image)
                image_tensor = image_tensor.unsqueeze(0).to(device)
                
                # 예측
                output = model(image_tensor)
                probabilities = softmax(output)[0]
                
                # 결과 저장
                video_name = os.path.basename(video_path)
                pred_label = 0 if probabilities[0] > probabilities[1] else 1
                predictions.append((video_name, pred_label))
                
            except Exception as e:
                print(f"Error processing {video_path}: {str(e)}")
    
    # 결과 저장
    with open(args.source_file, 'w') as f:
        f.write('path,y\n')
        for video_name, label in predictions:
            f.write(f"{video_name},{label}\n")
    
    # 예측 분포 출력
    labels = [p[1] for p in predictions]
    unique, counts = np.unique(labels, return_counts=True)
    print("\nPrediction distribution:")
    for label, count in zip(unique, counts):
        print(f"Label {label}: {count} ({count/len(labels)*100:.2f}%)")

def main():
    # 기본 설정값 가져오기
    args = get_default_args()
    
    # 전처리 설정
    transform = transforms.Compose([
        transforms.CenterCrop((299, 299)),
        transforms.ToTensor(),
        transforms.Normalize([0.5]*3, [0.5]*3)
    ])
    
    # 모델 생성
    model = xception(num_out_classes=args.num_classes, dropout=args.dropout)
    
    # 최고 성능 모델 불러오기
    model = load_best_model(model, args.save_dir)
    
    # 추론 수행
    inference(args, model, transform)

if __name__ == '__main__':
    main()
# Out:
# C:\Users\ksw9066\AppData\Local\Temp\ipykernel_20080\1850171385.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(latest_model_path)
# Loaded latest best model from best_model_epoch_1.pth
# Epoch: 1, Accuracy: 0.8696
# Found 400 test videos
# Processing videos: 100%|██████████| 400/400 [01:30<00:00,  4.44it/s]
# Prediction distribution:
# Label 0: 158 (39.50%)
# Label 1: 242 (60.50%)

# %%
import cv2
import os
import glob
import cv2
from tqdm import tqdm
from PIL import Image
import torch
import torch.nn as nn

def extract_frames_from_test_videos():
    # 테스트 비디오 경로에서 모든 mp4 파일 찾기
    test_videos = glob.glob(os.path.join(args.root_test, "*.mp4"))
    print(f"Found {len(test_videos)} test videos")
    
    # 프레임 저장 디렉토리
    frames_dir = os.path.join(args.root_test, "frames")
    os.makedirs(frames_dir, exist_ok=True)
    
    # 각 비디오에서 중간 프레임 추출
    extracted_frames = []
    for video_path in tqdm(test_videos, desc="Extracting frames"):
        # 비디오 파일명
        video_name = os.path.basename(video_path)
        frame_name = os.path.splitext(video_name)[0] + ".jpg"
        frame_path = os.path.join(frames_dir, frame_name)

        # 이미 프레임이 존재하는 경우 건너뛰기
        if os.path.exists(frame_path):
            print(f"Frame already exists for {video_name}, skipping...")
            extracted_frames.append(frame_path)
            continue
        
        # 비디오 읽기
        cap = cv2.VideoCapture(video_path)
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        middle_frame = total_frames // 2
        
        # 중간 프레임 추출
        cap.set(cv2.CAP_PROP_POS_FRAMES, middle_frame)
        ret, frame = cap.read()
        
        if ret:
            cv2.imwrite(frame_path, frame)
            extracted_frames.append(frame_path)
            
        cap.release()
    
    return extracted_frames

# 테스트 비디오에서 프레임 추출
print("Extracting frames from test videos...")
extracted_frames = extract_frames_from_test_videos()

# Inference 수행
print("Performing inference...")
m = nn.Softmax(dim=1)  # dim=1 추가하여 경고 메시지 제거

# 결과 파일 생성
save_csv = args.source_file
sc = open(save_csv, 'w')
sc.write('path,y\n')

with torch.no_grad():
    for image_path in tqdm(extracted_frames, desc="Inference"):
        try:
            # 이미지 로드 및 전처리
            image = Image.open(image_path)
            image = transform(image)
            image = torch.unsqueeze(image, dim=0)
            image = image.cuda(args.gpu, non_blocking=True)

            # 예측
            output = model(image)
            output = m(output)[0]

            # 파일명 추출 (mp4 확장자로 변경)
            video_name = os.path.splitext(os.path.basename(image_path))[0] + ".mp4"
            
            # 결과 저장
            label = "0" if output[0] > output[1] else "1"
            sc.write(f"{video_name},{label}\n")
            
        except Exception as e:
            print(f"Error processing {image_path}: {str(e)}")

sc.close()

# 결과 확인
print("\nChecking submission file...")
with open(save_csv, 'r') as f:
    lines = f.readlines()
    print(f"Total predictions: {len(lines)-1}")  # 헤더 제외
    print("\nFirst few lines:")
    for line in lines[:5]:
        print(line.strip())
# Out:
# Extracting frames from test videos...
# Found 400 test videos
# Extracting frames: 100%|██████████| 400/400 [00:00<00:00, 34714.59it/s]
# Frame already exists for aassnaulhq.mp4, skipping...
# Frame already exists for aayfryxljh.mp4, skipping...
# Frame already exists for acazlolrpz.mp4, skipping...
# Frame already exists for adohdulfwb.mp4, skipping...
# Frame already exists for ahjnxtiamx.mp4, skipping...
# Frame already exists for ajiyrjfyzp.mp4, skipping...
# Frame already exists for aktnlyqpah.mp4, skipping...
# Frame already exists for alrtntfxtd.mp4, skipping...
# Frame already exists for aomqqjipcp.mp4, skipping...
# Frame already exists for apedduehoy.mp4, skipping...
# Frame already exists for apvzjkvnwn.mp4, skipping...
# Frame already exists for aqrsylrzgi.mp4, skipping...
# Frame already exists for axfhbpkdlc.mp4, skipping...
# Frame already exists for ayipraspbn.mp4, skipping...
# Frame already exists for bcbqxhziqz.mp4, skipping...
# Frame already exists for bcvheslzrq.mp4, skipping...
# Frame already exists for bdshuoldwx.mp4, skipping...
# Frame already exists for bfdopzvxbi.mp4, skipping...
# Frame already exists for bfjsthfhbd.mp4, skipping...
# Frame already exists for bjyaxvggle.mp4, skipping...
# Frame already exists for bkcyglmfci.mp4, skipping...
# Frame already exists for bktkwbcawi.mp4, skipping...
# Frame already exists for bkuzquigyt.mp4, skipping...
# Frame already exists for blnmxntbey.mp4, skipping...
# Frame already exists for blszgmxkvu.mp4, skipping...
# Frame already exists for bnuwxhfahw.mp4, skipping...
# Frame already exists for bofrwgeyjo.mp4, skipping...
# Frame already exists for btdxnajogv.mp4, skipping...
# Frame already exists for bvpeerislp.mp4, skipping...
# Frame already exists for bwdmzwhdnw.mp4, skipping...
# Frame already exists for bzvzpwrabw.mp4, skipping...
# Frame already exists for cekarydqba.mp4, skipping...
# Frame already exists for cekwtyxdoo.mp4, skipping...
# Frame already exists for cjkctqqakb.mp4, skipping...
# Frame already exists for cnpanmywno.mp4, skipping...
# Frame already exists for cnxccbjlct.mp4, skipping...
# Frame already exists for coqwgzpbhx.mp4, skipping...
# Frame already exists for cosghhimnd.mp4, skipping...
# Frame already exists for coujjnypba.mp4, skipping...
# Frame already exists for cqhwesrciw.mp4, skipping...
# Frame already exists for cqxxumarvp.mp4, skipping...
# Frame already exists for csnkohqxdv.mp4, skipping...
# Frame already exists for cxsvvnxpyz.mp4, skipping...
# Frame already exists for czfqlbcfpa.mp4, skipping...
# Frame already exists for dcqodpzomd.mp4, skipping...
# Frame already exists for ddtbarpcgo.mp4, skipping...
# Frame already exists for demuhxssgl.mp4, skipping...
# Frame already exists for didzujjhtg.mp4, skipping...
# Frame already exists for dkuqbduxev.mp4, skipping...
# Frame already exists for dmmvuaikkv.mp4, skipping...
# Frame already exists for dnmowthjcj.mp4, skipping...
# Frame already exists for doniqevxeg.mp4, skipping...
# Frame already exists for dozjwhnedd.mp4, skipping...
# Frame already exists for dpevefkefv.mp4, skipping...
# Frame already exists for dpmgoiwhuf.mp4, skipping...
# Frame already exists for dsnxgrfdmd.mp4, skipping...
# Frame already exists for dtozwcapoa.mp4, skipping...
# Frame already exists for dvkdfhrpph.mp4, skipping...
# Frame already exists for dvtpwatuja.mp4, skipping...
# Frame already exists for dvwpvqdflx.mp4, skipping...
# Frame already exists for dxfdovivlw.mp4, skipping...
# Frame already exists for dxgnpnowgk.mp4, skipping...
# Frame already exists for dyjklprkoc.mp4, skipping...
# Frame already exists for dzkyxbbqkr.mp4, skipping...
# Frame already exists for dzojiwfvba.mp4, skipping...
# Frame already exists for ecumyiowzs.mp4, skipping...
# Frame already exists for eisofhptvk.mp4, skipping...
# Frame already exists for ekboxwrwuv.mp4, skipping...
# Frame already exists for ekelfsnqof.mp4, skipping...
# Frame already exists for ekvwecwltj.mp4, skipping...
# Frame already exists for elackxuccp.mp4, skipping...
# Frame already exists for eppyqpgewp.mp4, skipping...
# Frame already exists for eqslzbqfea.mp4, skipping...
# Frame already exists for eryjktdexi.mp4, skipping...
# Frame already exists for esjdyghhog.mp4, skipping...
# Frame already exists for esmqxszybs.mp4, skipping...
# Frame already exists for espkiocpxq.mp4, skipping...
# Frame already exists for etdliwticv.mp4, skipping...
# Frame already exists for evysmtpnrf.mp4, skipping...
# Frame already exists for eyguqfmgzh.mp4, skipping...
# Frame already exists for eywdmustbb.mp4, skipping...
# Frame already exists for famlupsgqm.mp4, skipping...
# Frame already exists for fddmkqjwsh.mp4, skipping...
# Frame already exists for fjrueenjyp.mp4, skipping...
# Frame already exists for fjxovgmwnm.mp4, skipping...
# Frame already exists for fmhiujydwo.mp4, skipping...
# Frame already exists for fmvvmcbdrw.mp4, skipping...
# Frame already exists for fneqiqpqvs.mp4, skipping...
# Frame already exists for fnxgqcvlsd.mp4, skipping...
# Frame already exists for fopjiyxiqd.mp4, skipping...
# Frame already exists for fpevfidstw.mp4, skipping...
# Frame already exists for fqgypsunzr.mp4, skipping...
# Frame already exists for frqfsucgao.mp4, skipping...
# Frame already exists for fsdrwikhge.mp4, skipping...
# Frame already exists for fwykevubzy.mp4, skipping...
# Frame already exists for fxuxxtryjn.mp4, skipping...
# Frame already exists for fzvpbrzssi.mp4, skipping...
# Frame already exists for gahgyuwzbu.mp4, skipping...
# Frame already exists for gbnzicjyhz.mp4, skipping...
# Frame already exists for gccnvdoknm.mp4, skipping...
# Frame already exists for gcdtglsoqj.mp4, skipping...
# Frame already exists for gfcycflhbo.mp4, skipping...
# Frame already exists for gfdjzwnpyp.mp4, skipping...
# Frame already exists for gfgcwxkbjd.mp4, skipping...
# Frame already exists for ggdpclfcgk.mp4, skipping...
# Frame already exists for ggzjfrirjh.mp4, skipping...
# Frame already exists for ghnpsltzyn.mp4, skipping...
# Frame already exists for gkutjglghz.mp4, skipping...
# Frame already exists for gochxzemmq.mp4, skipping...
# Frame already exists for gpsxfxrjrr.mp4, skipping...
# Frame already exists for gqnaxievjx.mp4, skipping...
# Frame already exists for gunamloolc.mp4, skipping...
# Frame already exists for halvwiltfs.mp4, skipping...
# Frame already exists for hbufmvbium.mp4, skipping...
# Frame already exists for hcanfkwivl.mp4, skipping...
# Frame already exists for hclsparpth.mp4, skipping...
# Frame already exists for hefisnapds.mp4, skipping...
# Frame already exists for heiyoojifp.mp4, skipping...
# Frame already exists for hevcclcklc.mp4, skipping...
# Frame already exists for hfsvqabzfq.mp4, skipping...
# Frame already exists for hicjuubiau.mp4, skipping...
# Frame already exists for hierggamuo.mp4, skipping...
# Frame already exists for hitfycdavv.mp4, skipping...
# Frame already exists for hnfwagcxdf.mp4, skipping...
# Frame already exists for honxqdilvv.mp4, skipping...
# Frame already exists for hqzwudvhih.mp4, skipping...
# Frame already exists for hsbljbsgxr.mp4, skipping...
# Frame already exists for hsbwhlolsn.mp4, skipping...
# Frame already exists for hszwwswewp.mp4, skipping...
# Frame already exists for htzbnroagi.mp4, skipping...
# Frame already exists for huvlwkxoxm.mp4, skipping...
# Frame already exists for hweshqpfwe.mp4, skipping...
# Frame already exists for hxwtsaydal.mp4, skipping...
# Frame already exists for hyjqolupxn.mp4, skipping...
# Frame already exists for hzoiotcykp.mp4, skipping...
# Frame already exists for hzssdinxec.mp4, skipping...
# Frame already exists for ibxfxggtqh.mp4, skipping...
# Frame already exists for icbsahlivv.mp4, skipping...
# Frame already exists for igpvrfjdzc.mp4, skipping...
# Frame already exists for ihglzxzroo.mp4, skipping...
# Frame already exists for iksxzpqxzi.mp4, skipping...
# Frame already exists for ilqwcbprqa.mp4, skipping...
# Frame already exists for imdmhwkkni.mp4, skipping...
# Frame already exists for iorbtaarte.mp4, skipping...
# Frame already exists for ipkpxvwroe.mp4, skipping...
# Frame already exists for ipvwtgdlre.mp4, skipping...
# Frame already exists for irqzdokcws.mp4, skipping...
# Frame already exists for itfsvvmslp.mp4, skipping...
# Frame already exists for iznnzjvaxc.mp4, skipping...
# Frame already exists for jawgcggquk.mp4, skipping...
# Frame already exists for jhczqfefgw.mp4, skipping...
# Frame already exists for jiavqbrkyk.mp4, skipping...
# Frame already exists for jiswxuqzyz.mp4, skipping...
# Frame already exists for jquevmhdvc.mp4, skipping...
# Frame already exists for jsbpkpxwew.mp4, skipping...
# Frame already exists for jsysgmycsx.mp4, skipping...
# Frame already exists for jyfvaequfg.mp4, skipping...
# Frame already exists for jyoxdvxpza.mp4, skipping...
# Frame already exists for jytrvwlewz.mp4, skipping...
# Frame already exists for jzmzdispyo.mp4, skipping...
# Frame already exists for kcjvhgvhpt.mp4, skipping...
# Frame already exists for keioymnobc.mp4, skipping...
# Frame already exists for kezwvsxxzj.mp4, skipping...
# Frame already exists for khpipxnsvx.mp4, skipping...
# Frame already exists for kmcdjxmnoa.mp4, skipping...
# Frame already exists for kmqkiihrmj.mp4, skipping...
# Frame already exists for knxltsvzyu.mp4, skipping...
# Frame already exists for kowiwvrjht.mp4, skipping...
# Frame already exists for kqlvggiqee.mp4, skipping...
# Frame already exists for kvmpmhdxly.mp4, skipping...
# Frame already exists for kwfdyqofzw.mp4, skipping...
# Frame already exists for lbfqksftuo.mp4, skipping...
# Frame already exists for lbigytrrtr.mp4, skipping...
# Frame already exists for lebzjtusnr.mp4, skipping...
# Frame already exists for lhvjzhjxdp.mp4, skipping...
# Frame already exists for ljauauuyka.mp4, skipping...
# Frame already exists for ljouzjaqqe.mp4, skipping...
# Frame already exists for llplvmcvbl.mp4, skipping...
# Frame already exists for lmdyicksrv.mp4, skipping...
# Frame already exists for lnhkjhyhvw.mp4, skipping...
# Frame already exists for lnjkpdviqb.mp4, skipping...
# Frame already exists for lpgxwdgnio.mp4, skipping...
# Frame already exists for lpkgabskbw.mp4, skipping...
# Frame already exists for lujvyveojc.mp4, skipping...
# Frame already exists for lyoslorecs.mp4, skipping...
# Frame already exists for mdfndlljvt.mp4, skipping...
# Frame already exists for mkmgcxaztt.mp4, skipping...
# Frame already exists for mkzaekkvej.mp4, skipping...
# Frame already exists for mllzkpgatp.mp4, skipping...
# Frame already exists for mnowxangqx.mp4, skipping...
# Frame already exists for mnzabbkpmt.mp4, skipping...
# Frame already exists for mohiqoogpb.mp4, skipping...
# Frame already exists for mszblrdprw.mp4, skipping...
# Frame already exists for mwnibuujwz.mp4, skipping...
# Frame already exists for mwwploizlj.mp4, skipping...
# Frame already exists for mxahsihabr.mp4, skipping...
# Frame already exists for mxlipjhmqk.mp4, skipping...
# Frame already exists for ncmpqwmnzb.mp4, skipping...
# Frame already exists for ncoeewrdlo.mp4, skipping...
# Frame already exists for ndikguxzek.mp4, skipping...
# Frame already exists for nikynwcvuh.mp4, skipping...
# Frame already exists for njzshtfmcw.mp4, skipping...
# Frame already exists for nkhzxomani.mp4, skipping...
# Frame already exists for novarhxpbj.mp4, skipping...
# Frame already exists for nplviymzlg.mp4, skipping...
# Frame already exists for nswtvttxre.mp4, skipping...
# Frame already exists for nthpnwylxo.mp4, skipping...
# Frame already exists for nwvloufjty.mp4, skipping...
# Frame already exists for nwvsbmyndn.mp4, skipping...
# Frame already exists for nxgzmgzkfv.mp4, skipping...
# Frame already exists for nxnmkytwze.mp4, skipping...
# Frame already exists for nxzgekegsp.mp4, skipping...
# Frame already exists for nycmyuzpml.mp4, skipping...
# Frame already exists for nymodlmxni.mp4, skipping...
# Frame already exists for oaguiggjyv.mp4, skipping...
# Frame already exists for ocgdbrgmtq.mp4, skipping...
# Frame already exists for oefukgnvel.mp4, skipping...
# Frame already exists for oelqpetgwj.mp4, skipping...
# Frame already exists for ojsxxkalat.mp4, skipping...
# Frame already exists for okgelildpc.mp4, skipping...
# Frame already exists for omphqltjdd.mp4, skipping...
# Frame already exists for ooafcxxfrs.mp4, skipping...
# Frame already exists for oocincvedt.mp4, skipping...
# Frame already exists for oojxonbgow.mp4, skipping...
# Frame already exists for opvqdabdap.mp4, skipping...
# Frame already exists for orekjthsef.mp4, skipping...
# Frame already exists for orixbcfvdz.mp4, skipping...
# Frame already exists for ouaowjmigq.mp4, skipping...
# Frame already exists for owaogcehvc.mp4, skipping...
# Frame already exists for oyqgwjdwaj.mp4, skipping...
# Frame already exists for oysopgovhu.mp4, skipping...
# Frame already exists for papagllumt.mp4, skipping...
# Frame already exists for pcoxcmtroa.mp4, skipping...
# Frame already exists for pcyswtgick.mp4, skipping...
# Frame already exists for pdswwyyntw.mp4, skipping...
# Frame already exists for pdufsewrec.mp4, skipping...
# Frame already exists for petmyhjclt.mp4, skipping...
# Frame already exists for phjvutxpoi.mp4, skipping...
# Frame already exists for pqdeutauqc.mp4, skipping...
# Frame already exists for pqthmvwonf.mp4, skipping...
# Frame already exists for prhmixykhr.mp4, skipping...
# Frame already exists for prwsfljdjo.mp4, skipping...
# Frame already exists for psesikjaxx.mp4, skipping...
# Frame already exists for ptbfnkajyi.mp4, skipping...
# Frame already exists for ptbnewtvon.mp4, skipping...
# Frame already exists for pxcfrszlgi.mp4, skipping...
# Frame already exists for pxjkzvqomp.mp4, skipping...
# Frame already exists for qarqtkvgby.mp4, skipping...
# Frame already exists for qcbkztamqc.mp4, skipping...
# Frame already exists for qclpbcbgeq.mp4, skipping...
# Frame already exists for qdqdsaiitt.mp4, skipping...
# Frame already exists for qhkzlnzruj.mp4, skipping...
# Frame already exists for qhsehzgxqj.mp4, skipping...
# Frame already exists for qlqhjcshpk.mp4, skipping...
# Frame already exists for qlvsqdroqo.mp4, skipping...
# Frame already exists for qooxnxqqjb.mp4, skipping...
# Frame already exists for qqnlrngaft.mp4, skipping...
# Frame already exists for qsjiypnjwi.mp4, skipping...
# Frame already exists for qswlzfgcgj.mp4, skipping...
# Frame already exists for qxyrtwozyw.mp4, skipping...
# Frame already exists for qyyhuvqmyf.mp4, skipping...
# Frame already exists for rcecrgeotc.mp4, skipping...
# Frame already exists for rcjfxxhcal.mp4, skipping...
# Frame already exists for rerpivllud.mp4, skipping...
# Frame already exists for rfjuhbnlro.mp4, skipping...
# Frame already exists for rfwxcinshk.mp4, skipping...
# Frame already exists for rklawjhbpv.mp4, skipping...
# Frame already exists for rktrpsdlci.mp4, skipping...
# Frame already exists for rmlzgerevr.mp4, skipping...
# Frame already exists for rmufsuogzn.mp4, skipping...
# Frame already exists for rnfcjxynfa.mp4, skipping...
# Frame already exists for rrrfjhugvb.mp4, skipping...
# Frame already exists for rtpbawlmxr.mp4, skipping...
# Frame already exists for ruhtnngrqv.mp4, skipping...
# Frame already exists for rukyxomwcx.mp4, skipping...
# Frame already exists for rvvpazsffd.mp4, skipping...
# Frame already exists for rxdoimqble.mp4, skipping...
# Frame already exists for ryxaqpfubf.mp4, skipping...
# Frame already exists for scbdenmaed.mp4, skipping...
# Frame already exists for scrbqgpvzz.mp4, skipping...
# Frame already exists for sfsayjgzrh.mp4, skipping...
# Frame already exists for shnsajrsow.mp4, skipping...
# Frame already exists for siebfpwuhu.mp4, skipping...
# Frame already exists for sjinmmbipg.mp4, skipping...
# Frame already exists for sjkfxrlxxs.mp4, skipping...
# Frame already exists for sjwywglgym.mp4, skipping...
# Frame already exists for sktpeppbkc.mp4, skipping...
# Frame already exists for sngjsueuhs.mp4, skipping...
# Frame already exists for snlyjbnpgw.mp4, skipping...
# Frame already exists for sodvtfqbpf.mp4, skipping...
# Frame already exists for sqixhnilfm.mp4, skipping...
# Frame already exists for srfefmyjvt.mp4, skipping...
# Frame already exists for sufvvwmbha.mp4, skipping...
# Frame already exists for swsaoktwgi.mp4, skipping...
# Frame already exists for sylnrepacf.mp4, skipping...
# Frame already exists for syuxttuyhm.mp4, skipping...
# Frame already exists for syxobtuucp.mp4, skipping...
# Frame already exists for sznkemeqro.mp4, skipping...
# Frame already exists for tejfudfgpq.mp4, skipping...
# Frame already exists for temeqbmzxu.mp4, skipping...
# Frame already exists for temjefwaas.mp4, skipping...
# Frame already exists for tgawasvbbr.mp4, skipping...
# Frame already exists for tjuihawuqm.mp4, skipping...
# Frame already exists for tjywwgftmv.mp4, skipping...
# Frame already exists for toinozytsp.mp4, skipping...
# Frame already exists for tvhjcfnqtg.mp4, skipping...
# Frame already exists for txmnoyiyte.mp4, skipping...
# Frame already exists for txnmkabufs.mp4, skipping...
# Frame already exists for tyjpjpglgx.mp4, skipping...
# Frame already exists for tynfsthodx.mp4, skipping...
# Frame already exists for ucthmsajay.mp4, skipping...
# Frame already exists for udxqbhgvvx.mp4, skipping...
# Frame already exists for uhakqelqri.mp4, skipping...
# Frame already exists for uhrqlmlclw.mp4, skipping...
# Frame already exists for uoccaiathd.mp4, skipping...
# Frame already exists for upmgtackuf.mp4, skipping...
# Frame already exists for uqvxjfpwdo.mp4, skipping...
# Frame already exists for usqqvxcjmg.mp4, skipping...
# Frame already exists for uubgqnvfdl.mp4, skipping...
# Frame already exists for uvrzaczrbx.mp4, skipping...
# Frame already exists for uxuvkrjhws.mp4, skipping...
# Frame already exists for vajkicalux.mp4, skipping...
# Frame already exists for vbcgoyxsvn.mp4, skipping...
# Frame already exists for vdtsbqidjb.mp4, skipping...
# Frame already exists for vhbbwdflyh.mp4, skipping...
# Frame already exists for viteugozpv.mp4, skipping...
# Frame already exists for vizerpsvbz.mp4, skipping...
# Frame already exists for vjljdfopjg.mp4, skipping...
# Frame already exists for vmxfwxgdei.mp4, skipping...
# Frame already exists for vnlzxqwthl.mp4, skipping...
# Frame already exists for voawxrmqyl.mp4, skipping...
# Frame already exists for vokrpfjpeb.mp4, skipping...
# Frame already exists for vssmlqoiti.mp4, skipping...
# Frame already exists for vtunvalyji.mp4, skipping...
# Frame already exists for vurjckblge.mp4, skipping...
# Frame already exists for vvfszaosiv.mp4, skipping...
# Frame already exists for vwxednhlwz.mp4, skipping...
# Frame already exists for wadvzjhwtw.mp4, skipping...
# Frame already exists for waucvvmtkq.mp4, skipping...
# Frame already exists for wclvkepakb.mp4, skipping...
# Frame already exists for wcqvzujamg.mp4, skipping...
# Frame already exists for wcssbghcpc.mp4, skipping...
# Frame already exists for wcvsqnplsk.mp4, skipping...
# Frame already exists for wfzjxzhdkj.mp4, skipping...
# Frame already exists for wixbuuzygv.mp4, skipping...
# Frame already exists for wjhpisoeaj.mp4, skipping...
# Frame already exists for wmoqzxddkb.mp4, skipping...
# Frame already exists for wndursivcx.mp4, skipping...
# Frame already exists for wnlubukrki.mp4, skipping...
# Frame already exists for wqysrieiqu.mp4, skipping...
# Frame already exists for wvgviwnwob.mp4, skipping...
# Frame already exists for wynotylpnm.mp4, skipping...
# Frame already exists for xcruhaccxc.mp4, skipping...
# Frame already exists for xdezcezszc.mp4, skipping...
# Frame already exists for xhtppuyqdr.mp4, skipping...
# Frame already exists for xitgdpzbxv.mp4, skipping...
# Frame already exists for xjvxtuakyd.mp4, skipping...
# Frame already exists for xljemofssi.mp4, skipping...
# Frame already exists for xmkwsnuzyq.mp4, skipping...
# Frame already exists for xphdfgmfmz.mp4, skipping...
# Frame already exists for xrtvqhdibb.mp4, skipping...
# Frame already exists for xugmhbetrw.mp4, skipping...
# Frame already exists for xxzefxwyku.mp4, skipping...
# Frame already exists for yarpxfqejd.mp4, skipping...
# Frame already exists for yaxgpxhavq.mp4, skipping...
# Frame already exists for ybbrkacebd.mp4, skipping...
# Frame already exists for yhjlnisfel.mp4, skipping...
# Frame already exists for yhylappzid.mp4, skipping...
# Frame already exists for yietrwuncf.mp4, skipping...
# Frame already exists for yiykshcbaz.mp4, skipping...
# Frame already exists for yljecirelf.mp4, skipping...
# Frame already exists for yllztsrwjw.mp4, skipping...
# Frame already exists for ylxwcwhjjd.mp4, skipping...
# Frame already exists for yoyhmxtrys.mp4, skipping...
# Frame already exists for ypbtpunjvm.mp4, skipping...
# Frame already exists for yqhouqakbx.mp4, skipping...
# Frame already exists for yronlutbgm.mp4, skipping...
# Frame already exists for ystdtnetgj.mp4, skipping...
# Frame already exists for ytddugrwph.mp4, skipping...
# Frame already exists for ytopzxrswu.mp4, skipping...
# Frame already exists for ywauoonmlr.mp4, skipping...
# Frame already exists for ywxpquomgt.mp4, skipping...
# Frame already exists for yxadevzohx.mp4, skipping...
# Frame already exists for yxirnfyijn.mp4, skipping...
# Frame already exists for yxvmusxvcz.mp4, skipping...
# Frame already exists for yzuestxcbq.mp4, skipping...
# Frame already exists for zbgssotnjm.mp4, skipping...
# Frame already exists for zcxcmneefk.mp4, skipping...
# Frame already exists for zfobicuigx.mp4, skipping...
# Frame already exists for zfrrixsimm.mp4, skipping...
# Frame already exists for zgbhzkditd.mp4, skipping...
# Frame already exists for zgjosltkie.mp4, skipping...
# Frame already exists for ziipxxchai.mp4, skipping...
# Frame already exists for zmxeiipnqb.mp4, skipping...
# Frame already exists for ztyuiqrhdk.mp4, skipping...
# Frame already exists for ztyvglkcsf.mp4, skipping...
# Frame already exists for zuwwbbusgl.mp4, skipping...
# Frame already exists for zxacihctqp.mp4, skipping...
# Frame already exists for zyufpqvpyu.mp4, skipping...
# Frame already exists for zzmgnglanj.mp4, skipping...
# Performing inference...
# Inference: 100%|██████████| 400/400 [00:09<00:00, 42.96it/s]
# Checking submission file...
# Total predictions: 400
#
# First few lines:
# path,y
# aassnaulhq.mp4,0
# aayfryxljh.mp4,1
# acazlolrpz.mp4,1
# adohdulfwb.mp4,0

# %%
import numpy as np
import torch
import torch.nn as nn
from PIL import Image
from tqdm import tqdm
import os
from glob import glob

print("Starting inference...")
m = nn.Softmax(dim=1)

# 결과 파일 열기
with open(save_csv, 'w') as sc:
    # 헤더 작성
    sc.write('path,y\n')
    
    with torch.no_grad():
        # 처음 5개 이미지 자세히 분석
        for idx, image_path in enumerate(extracted_frames[:5]):
            try:
                # 이미지 로드 및 전처리
                image = Image.open(image_path)
                print(f"\nProcessing image {idx}: {image_path}")
                print(f"Original image size: {image.size}")
                
                # 전처리 단계별 확인
                image_tensor = transform(image)
                print(f"Transformed tensor shape: {image_tensor.shape}")
                print(f"Tensor range: [{image_tensor.min():.2f}, {image_tensor.max():.2f}]")
                
                # 배치 차원 추가
                image_tensor = torch.unsqueeze(image_tensor, dim=0)
                image_tensor = image_tensor.cuda(args.gpu, non_blocking=True)

                # 예측
                output = model(image_tensor)
                print(f"Raw model output: {output[0].cpu().numpy()}")
                
                # Softmax 적용
                probabilities = m(output)[0]
                print(f"Probabilities: {probabilities.cpu().numpy()}")
                
                # 예측 결과
                pred_label = 0 if probabilities[0] > probabilities[1] else 1
                confidence = float(max(probabilities[0], probabilities[1]))
                
                print(f"Predicted label: {pred_label} (confidence: {confidence:.4f})")

                # 결과 저장
                video_name = os.path.splitext(os.path.basename(image_path))[0] + ".mp4"
                sc.write(f"{video_name},{pred_label}\n")

            except Exception as e:
                print(f"Error processing {image_path}: {str(e)}")

        # 나머지 이미지 처리
        for image_path in tqdm(extracted_frames[5:], desc="Processing remaining"):
            try:
                image = Image.open(image_path)
                image_tensor = transform(image)
                image_tensor = torch.unsqueeze(image_tensor, dim=0)
                image_tensor = image_tensor.cuda(args.gpu, non_blocking=True)
                
                output = model(image_tensor)
                probabilities = m(output)[0]
                pred_label = 0 if probabilities[0] > probabilities[1] else 1
                
                video_name = os.path.splitext(os.path.basename(image_path))[0] + ".mp4"
                sc.write(f"{video_name},{pred_label}\n")
            except Exception as e:
                print(f"Error processing {image_path}: {str(e)}")

print("\nChecking predictions distribution...")
# 예측 분포 확인
with open(save_csv, 'r') as f:
    lines = f.readlines()[1:]  # 헤더 제외
    predictions = [int(line.strip().split(',')[1]) for line in lines]
    unique, counts = np.unique(predictions, return_counts=True)
    for label, count in zip(unique, counts):
        print(f"Label {label}: {count} ({count/len(predictions)*100:.2f}%)")
# Out:
# Starting inference...
#
# Processing image 0: D:/01.deepfake/test_videos\frames\aassnaulhq.jpg
# Original image size: (1920, 1080)
# Transformed tensor shape: torch.Size([3, 299, 299])
# Tensor range: [-1.00, 0.15]
# Raw model output: [ 0.5769574 -0.611828 ]
# Probabilities: [0.7665238  0.23347625]
# Predicted label: 0 (confidence: 0.7665)
#
# Processing image 1: D:/01.deepfake/test_videos\frames\aayfryxljh.jpg
# Original image size: (1920, 1080)
# Transformed tensor shape: torch.Size([3, 299, 299])
# Tensor range: [-1.00, 1.00]
# Raw model output: [-0.6790594  0.6696099]
# Probabilities: [0.206088 0.793912]
# Predicted label: 1 (confidence: 0.7939)
#
# Processing image 2: D:/01.deepfake/test_videos\frames\acazlolrpz.jpg
# Original image size: (1920, 1080)
# Transformed tensor shape: torch.Size([3, 299, 299])
# Tensor range: [-1.00, 1.00]
# Raw model output: [-1.3310783  1.4114515]
# Probabilities: [0.06050992 0.93949   ]
# Predicted label: 1 (confidence: 0.9395)
#
# Processing image 3: D:/01.deepfake/test_videos\frames\adohdulfwb.jpg
# Original image size: (1920, 1080)
# Transformed tensor shape: torch.Size([3, 299, 299])
# Tensor range: [-1.00, 0.68]
# Raw model output: [ 0.5251474 -0.5663938]
# Probabilities: [0.7486718 0.2513282]
# Predicted label: 0 (confidence: 0.7487)
#
# Processing image 4: D:/01.deepfake/test_videos\frames\ahjnxtiamx.jpg
# Original image size: (1920, 1080)
# Transformed tensor shape: torch.Size([3, 299, 299])
# Tensor range: [-1.00, 1.00]
# Raw model output: [-2.2642424  2.12629  ]
# Probabilities: [0.0122424 0.9877577]
# Predicted label: 1 (confidence: 0.9878)
# Processing remaining: 100%|██████████| 395/395 [00:09<00:00, 42.43it/s]
# Checking predictions distribution...
# Label 0: 158 (39.50%)
# Label 1: 242 (60.50%)

# %%
args = easydict.EasyDict({
    "gpu": 0,
    "num_workers": 4,
    "root": "D:/01.deepfake/dfdc_train_part_0 - 복사본",
    "train_list": "D:/01.deepfake/dfdc_train_part_0 - 복사본/train_list_1st.txt",
    "valid_list": "D:/01.deepfake/dfdc_train_part_0 - 복사본/test_list_1st.txt",
    "learning_rate": 0.001,
    "num_epochs": 1,
    "batch_size": 16,
    "save_fn": "D:/01.deepfake/models/deepfake_c0_xception_tuned.pth.tar",
})

# %%
def create_train_valid_lists(frames_path, train_ratio=0.8):
    real_images = glob(os.path.join(frames_path, "real", "*.jpg"))
    fake_images = glob(os.path.join(frames_path, "fake", "*.jpg"))

    random.shuffle(real_images)
    random.shuffle(fake_images)

    real_split = int(len(real_images) * train_ratio)
    fake_split = int(len(fake_images) * train_ratio)

    train_images = real_images[:real_split] + fake_images[:fake_split]
    valid_images = real_images[real_split:] + fake_images[fake_split:]

# %%
train_dataset = DFDCDatatset(
    args.root,
    args.train_list,
    xception_default["train"]
)

valid_dataset = DFDCDatatset(
    args.root,
    args.valid_list,
    xception_default["valid"]
)

# %%
# Dataset 생성
train_dataset = DFDCDatatset(args.root, args.train_list, xception_default["train"])
valid_dataset = DFDCDatatset(args.root, args.valid_list, xception_default["valid"])

print(f"Training dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(valid_dataset)}")

# DataLoader 생성
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=args.batch_size, shuffle=False)
# Out:
# Training dataset size: 4135
# Validation dataset size: 1035

# %%
train_dataset = DFDCDatatset(args.root, args.train_list, xception_default["train"])
valid_dataset = DFDCDatatset(args.root, args.valid_list, xception_default["valid"])

# %%
import json
import os

def create_train_valid_lists(metadata_path, video_dir, output_dir, train_ratio=0.8):
    # Metadata 파일 로드
    with open(metadata_path, "r") as f:
        metadata = json.load(f)

    # REAL과 FAKE 데이터 분리
    real_videos = [video for video, info in metadata.items() if info["label"] == "REAL"]
    fake_videos = [video for video, info in metadata.items() if info["label"] == "FAKE"]

    # 섞기
    import random
    random.shuffle(real_videos)
    random.shuffle(fake_videos)

    # Train/Validation split
    real_split = int(len(real_videos) * train_ratio)
    fake_split = int(len(fake_videos) * train_ratio)

    train_videos = real_videos[:real_split] + fake_videos[:fake_split]
    valid_videos = real_videos[real_split:] + fake_videos[fake_split:]

    # 파일 생성
    os.makedirs(output_dir, exist_ok=True)

    def save_list(video_list, filename):
        with open(os.path.join(output_dir, filename), "w") as f:
            for video in video_list:
                label = "0" if video in real_videos else "1"  # 0: REAL, 1: FAKE
                f.write(f"{os.path.join(video_dir, video)} {label}\n")

    save_list(train_videos, "train_list.txt")
    save_list(valid_videos, "valid_list.txt")

    print(f"Train videos: {len(train_videos)} (REAL: {len(real_videos[:real_split])}, FAKE: {len(fake_videos[:fake_split])})")
    print(f"Validation videos: {len(valid_videos)} (REAL: {len(real_videos[real_split:])}, FAKE: {len(fake_videos[fake_split:])})")

# 경로 설정
metadata_path = "D:/01.deepfake/dfdc_train_part_0 - 복사본/metadata.json"
video_dir = "D:/01.deepfake/dfdc_train_part_0 - 복사본/videos"
output_dir = "D:/01.deepfake/dfdc_train_part_0 - 복사본"

# Train/Validation 리스트 생성
create_train_valid_lists(metadata_path, video_dir, output_dir)
# Out:
# Train videos: 4135 (REAL: 1923, FAKE: 2212)
# Validation videos: 1035 (REAL: 481, FAKE: 554)

# %%
# import os
# import json

# # 폴더 경로 설정
# base_path = r"D:\임시\새 폴더"
# folders = [f"dfdc_train_part_{i}" for i in range(2, 10)]  # dfdc_train_part_2 to dfdc_train_part_9

# # REAL 데이터 갯수 계산
# real_counts = {}

# for folder in folders:
#     folder_path = os.path.join(base_path, folder)
#     metadata_path = os.path.join(folder_path, "metadata.json")
    
#     if os.path.exists(metadata_path):  # Check if metadata.json exists
#         with open(metadata_path, "r") as f:
#             metadata = json.load(f)
        
#         # Count REAL labels
#         real_count = sum(1 for item in metadata.values() if item["label"] == "REAL")
#         real_counts[folder] = real_count
#     else:
#         print(f"metadata.json not found in {folder_path}")

# # 결과 출력
# for folder, count in real_counts.items():
#     print(f"{folder}: {count} REAL videos")

# %%
# import os
# import json
# import shutil

# # 원본 폴더 및 대상 폴더 경로 설정
# source_base_path = r"D:\임시\새 폴더"
# destination_path = r"D:\01.deepfake\dfdc_train_part_0 - 복사본"
# folders = [f"dfdc_train_part_{i}" for i in range(2, 10)]  # dfdc_train_part_2 to dfdc_train_part_9

# # 대상 폴더에 metadata.json 파일 초기화
# metadata_file = os.path.join(destination_path, "metadata.json")
# if not os.path.exists(destination_path):
#     os.makedirs(destination_path)
# if not os.path.exists(metadata_file):
#     with open(metadata_file, "w") as f:
#         json.dump({}, f)

# # 기존 metadata.json 읽기
# with open(metadata_file, "r") as f:
#     combined_metadata = json.load(f)

# # REAL 데이터 복사 및 메타데이터 업데이트
# for folder in folders:
#     folder_path = os.path.join(source_base_path, folder)
#     metadata_path = os.path.join(folder_path, "metadata.json")
    
#     if os.path.exists(metadata_path):  # Check if metadata.json exists
#         with open(metadata_path, "r") as f:
#             metadata = json.load(f)
        
#         for file_name, data in metadata.items():
#             if data["label"] == "REAL":
#                 source_file = os.path.join(folder_path, file_name)
#                 destination_file = os.path.join(destination_path, file_name)
                
#                 if os.path.exists(source_file):  # Check if source file exists
#                     # 파일 복사
#                     shutil.copy2(source_file, destination_file)
                    
#                     # 메타데이터 추가
#                     combined_metadata[file_name] = data
#                 else:
#                     print(f"File not found: {source_file}")
#     else:
#         print(f"metadata.json not found in {folder_path}")

# # 업데이트된 metadata.json 저장
# with open(metadata_file, "w") as f:
#     json.dump(combined_metadata, f, indent=4)

# print("REAL 데이터 복사 및 메타데이터 업데이트 완료!")

# %%
# import os
# import json
# import shutil

# # 경로 설정
# source_folder = r"D:\임시\새 폴더\dfdc_train_part_2"
# destination_folder = r"D:\01.deepfake\dfdc_train_part_0 - 복사본"
# source_metadata_file = os.path.join(source_folder, "metadata.json")
# destination_metadata_file = os.path.join(destination_folder, "metadata.json")

# # 대상 폴더와 metadata.json 초기화
# if not os.path.exists(destination_folder):
#     os.makedirs(destination_folder)
# if not os.path.exists(destination_metadata_file):
#     with open(destination_metadata_file, "w") as f:
#         json.dump({}, f)

# # 기존 metadata.json 읽기
# with open(destination_metadata_file, "r") as f:
#     destination_metadata = json.load(f)

# # 원본 metadata.json 읽기
# if not os.path.exists(source_metadata_file):
#     print(f"metadata.json not found in {source_folder}")
# else:
#     with open(source_metadata_file, "r") as f:
#         source_metadata = json.load(f)

#     # FAKE 라벨의 동영상 파일 복사 및 메타데이터 업데이트
#     for file_name, data in source_metadata.items():
#         if data["label"] == "FAKE":
#             source_file = os.path.join(source_folder, file_name)
#             destination_file = os.path.join(destination_folder, file_name)
            
#             if os.path.exists(source_file):  # 파일이 존재하는 경우에만 처리
#                 # 파일 복사
#                 shutil.copy2(source_file, destination_file)
                
#                 # 메타데이터 업데이트
#                 destination_metadata[file_name] = data
#             else:
#                 print(f"File not found: {source_file}")

#     # 업데이트된 metadata.json 저장
#     with open(destination_metadata_file, "w") as f:
#         json.dump(destination_metadata, f, indent=4)

# print("FAKE 데이터 복사 및 메타데이터 업데이트 완료!")
