# %%
import os
import json
import numpy as np
import torch
from facenet_pytorch import MTCNN, InceptionResnetV1
from PIL import Image
import cv2

# MPS 장치 확인
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device for FaceNet: {device}")

# MTCNN은 CPU에서 실행하고, InceptionResnetV1은 MPS에서 실행
mtcnn = MTCNN(keep_all=True, device="cpu")  # MTCNN을 CPU에서 실행
resnet = InceptionResnetV1(pretrained='vggface2').eval().to(device)  # FaceNet을 MPS에서 실행

# JSON 파일 경로와 동영상 폴더 설정
json_path = '/Users/gible/오픈소스sw/Train_Data/train_data/metadata.json'
video_folder = '/Users/gible/오픈소스sw/Train_Data/train_data/train_sample_videos'
output_folder = '/Users/gible/오픈소스sw/Train_Data/train_data/Embedding_data'

# JSON 파일 로드
with open(json_path, 'r') as f:
    metadata = json.load(f)

# 결과 저장 폴더 생성
os.makedirs(output_folder, exist_ok=True)

# Prewhiten 함수 정의
def prewhiten(x):
    mean = np.mean(x)
    std = np.std(x)
    std_adj = np.maximum(std, 1.0/np.sqrt(x.size))
    y = (x - mean) / std_adj
    return y

def process_video(video_path, label, output_path):
    cap = cv2.VideoCapture(video_path)
    embeddings = []
    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # OpenCV 이미지에서 PIL 이미지로 변환
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        pil_image = Image.fromarray(frame_rgb)

        # MTCNN을 사용하여 얼굴 추출 (CPU)
        boxes, _ = mtcnn.detect(pil_image)
        
        if boxes is not None:
            faces = []
            for box in boxes:
                # 얼굴 이미지 crop 및 리사이즈
                face = pil_image.crop((box[0], box[1], box[2], box[3])).resize((160, 160))
                faces.append(face)

            # 얼굴 임베딩 계산 (MPS)
            faces = [prewhiten(np.array(face)) for face in faces]
            face_tensors = torch.stack([torch.tensor(face, dtype=torch.float32).permute(2, 0, 1) for face in faces]).to(device)
            with torch.no_grad():
                face_embeddings = resnet(face_tensors)
                embeddings.append(face_embeddings.cpu().numpy())
        
        frame_count += 1

        # 예시로 매 10 프레임마다 추출
        if frame_count >= 10:
            break

    cap.release()

    # 임베딩 배열로 저장
    embeddings = np.vstack(embeddings) if embeddings else np.array([])
    if embeddings.size > 0:
        np.save(output_path, embeddings)

# 각 동영상 처리
for video_name, data in metadata.items():
    label = data['label']
    video_path = os.path.join(video_folder, video_name)
    output_path = os.path.join(output_folder, f"{video_name.split('.')[0]}_embedding.npy")

    if os.path.exists(video_path):
        process_video(video_path, label, output_path)
        print(f"Processed {video_name} with label {label}")
    else:
        print(f"Video file {video_name} not found")
# Out:
# Using device for FaceNet: mps
# Processed aagfhgtpmv.mp4 with label FAKE
# Processed aapnvogymq.mp4 with label FAKE
# Processed abarnvbtwb.mp4 with label REAL
# Processed abofeumbvv.mp4 with label FAKE
# Processed abqwwspghj.mp4 with label FAKE
# Processed acifjvzvpm.mp4 with label FAKE
# Processed acqfdwsrhi.mp4 with label FAKE
# Processed acxnxvbsxk.mp4 with label FAKE
# Processed acxwigylke.mp4 with label FAKE
# Processed aczrgyricp.mp4 with label FAKE
# Processed adhsbajydo.mp4 with label FAKE
# Processed adohikbdaz.mp4 with label FAKE
# Processed adylbeequz.mp4 with label FAKE
# Processed aelfnikyqj.mp4 with label REAL
# Processed aelzhcnwgf.mp4 with label FAKE
# Processed aettqgevhz.mp4 with label FAKE
# Processed aevrfsexku.mp4 with label FAKE
# Processed afoovlsmtx.mp4 with label REAL
# Processed agdkmztvby.mp4 with label FAKE
# Processed agqphdxmwt.mp4 with label FAKE
# Processed agrmhtjdlk.mp4 with label REAL
# Processed ahbweevwpv.mp4 with label FAKE
# Processed ahdbuwqxit.mp4 with label FAKE
# Processed ahfazfbntc.mp4 with label FAKE
# Processed ahqqqilsxt.mp4 with label REAL
# Processed aipfdnwpoo.mp4 with label FAKE
# Processed ajqslcypsw.mp4 with label REAL
# Processed ajwpjhrbcv.mp4 with label FAKE
# Processed aklqzsddfl.mp4 with label FAKE
# Processed aknbdpmgua.mp4 with label FAKE
# Processed aknmpoonls.mp4 with label FAKE
# Processed akvmwkdyuv.mp4 with label FAKE
# Processed akxoopqjqz.mp4 with label FAKE
# Processed akzbnazxtz.mp4 with label FAKE
# Processed aladcziidp.mp4 with label FAKE
# Processed alaijyygdv.mp4 with label FAKE
# Processed alninxcyhg.mp4 with label FAKE
# Processed altziddtxi.mp4 with label FAKE
# Processed alvgwypubw.mp4 with label FAKE
# Processed amaivqofda.mp4 with label FAKE
# Processed amowujxmzc.mp4 with label FAKE
# Processed andaxzscny.mp4 with label FAKE
# Processed aneclqfpbt.mp4 with label FAKE
# Processed anpuvshzoo.mp4 with label REAL
# Processed aorjvbyxhw.mp4 with label FAKE
# Processed apatcsqejh.mp4 with label FAKE
# Processed apgjqzkoma.mp4 with label FAKE
# Processed apogckdfrz.mp4 with label FAKE
# Processed aqpnvjhuzw.mp4 with label FAKE
# Processed arkroixhey.mp4 with label FAKE
# Processed arlmiizoob.mp4 with label FAKE
# Processed arrhsnjqku.mp4 with label FAKE
# Processed asaxgevnnp.mp4 with label REAL
# Processed asdpeebotb.mp4 with label FAKE
# Processed aslsvlvpth.mp4 with label FAKE
# Processed asmpfjfzif.mp4 with label FAKE
# Processed asvcrfdpnq.mp4 with label FAKE
# Processed atkdltyyen.mp4 with label REAL
# Processed atvmxvwyns.mp4 with label REAL
# Processed atxvxouljq.mp4 with label FAKE
# Processed atyntldecu.mp4 with label FAKE
# Processed atzdznmder.mp4 with label FAKE
# Processed aufmsmnoye.mp4 with label FAKE
# Processed augtsuxpzc.mp4 with label FAKE
# Processed avfitoutyn.mp4 with label FAKE
# Processed avgiuextiz.mp4 with label FAKE
# Processed avibnnhwhp.mp4 with label FAKE
# Processed avmjormvsx.mp4 with label REAL
# Processed avnqydkqjj.mp4 with label FAKE
# Processed avssvvsdhz.mp4 with label FAKE
# Processed avtycwsgyb.mp4 with label FAKE
# Processed avvdgsennp.mp4 with label FAKE
# Processed avywawptfc.mp4 with label FAKE
# Processed awhmfnnjih.mp4 with label FAKE
# Processed awnwkrqibf.mp4 with label FAKE
# Processed awukslzjra.mp4 with label FAKE
# Processed axczxisdtb.mp4 with label FAKE
# Processed axntxmycwd.mp4 with label REAL
# Processed axoygtekut.mp4 with label FAKE
# Processed axwgcsyphv.mp4 with label FAKE
# Processed axwovszumc.mp4 with label FAKE
# Processed aybgughjxh.mp4 with label REAL
# Processed aybumesmpk.mp4 with label REAL
# Processed ayqvfdhslr.mp4 with label FAKE
# Processed aytzyidmgs.mp4 with label REAL
# Processed azpuxunqyo.mp4 with label FAKE
# Processed azsmewqghg.mp4 with label FAKE
# Processed bahdpoesir.mp4 with label FAKE
# Processed bbhpvrmbse.mp4 with label FAKE
# Processed bbhtdfuqxq.mp4 with label FAKE
# Processed bbvgxeczei.mp4 with label FAKE
# Processed bchnbulevv.mp4 with label FAKE
# Processed bctvsmddgq.mp4 with label FAKE
# Processed bdbhekrrwo.mp4 with label FAKE
# Processed bddjdhzfze.mp4 with label REAL
# Processed bdgipnyobr.mp4 with label FAKE
# Processed bdnaqemxmr.mp4 with label REAL
# Processed bdxuhamuqx.mp4 with label FAKE
# Processed beboztfcme.mp4 with label REAL
# Processed bejhvclboh.mp4 with label REAL
# Processed benmsfzfaz.mp4 with label FAKE
# Processed beyebyhrph.mp4 with label REAL
# Processed bffwsjxghk.mp4 with label REAL
# Processed bgaogsjehq.mp4 with label FAKE
# Processed bggsurpgpr.mp4 with label FAKE
# Processed bghphrsfxf.mp4 with label FAKE
# Processed bgmlwsoamc.mp4 with label FAKE
# Processed bguwlyazau.mp4 with label FAKE
# Processed bgvhtpzknn.mp4 with label REAL
# Processed bgwmmujlmc.mp4 with label REAL
# Processed bhaaboftbc.mp4 with label FAKE
# Processed bhbdugnurr.mp4 with label FAKE
# Processed bhpwpydzpo.mp4 with label FAKE
# Processed bhsluedavd.mp4 with label FAKE
# Processed bilnggbxgu.mp4 with label REAL
# Processed bjjbwsqjir.mp4 with label FAKE
# Processed bjkmjilrxp.mp4 with label FAKE
# Processed bjsmaqefoi.mp4 with label FAKE
# Processed bkmdzhfzfh.mp4 with label FAKE
# Processed bkvetcojbt.mp4 with label FAKE
# Processed bkwxhglwct.mp4 with label FAKE
# Processed blpchvmhxx.mp4 with label FAKE
# Processed blzydqdfem.mp4 with label FAKE
# Processed bmbbkwmxqj.mp4 with label FAKE
# Processed bmehkyanbj.mp4 with label FAKE
# Processed bmhvktyiwp.mp4 with label FAKE
# Processed bmioepcpsx.mp4 with label FAKE
# Processed bmjmjmbglm.mp4 with label FAKE
# Processed bmjzrlszhi.mp4 with label REAL
# Processed bnbuonyoje.mp4 with label FAKE
# Processed bndybcqhfr.mp4 with label FAKE
# Processed bnjcdrfuov.mp4 with label FAKE
# Processed bntlodcfeg.mp4 with label FAKE
# Processed bofqajtwve.mp4 with label FAKE
# Processed boovltmuwi.mp4 with label FAKE
# Processed bopqhhalml.mp4 with label FAKE
# Processed bourlmzsio.mp4 with label FAKE
# Processed bpapbctoao.mp4 with label REAL
# Processed bpwzipqtxf.mp4 with label FAKE
# Processed bpxckdzddv.mp4 with label FAKE
# Processed bqdjzqhcft.mp4 with label FAKE
# Processed bqeiblbxtl.mp4 with label FAKE
# Processed bqhtpqmmqp.mp4 with label FAKE
# Processed bqkdbcqjvb.mp4 with label FAKE
# Processed bqnymlsayl.mp4 with label FAKE
# Processed bqqpbzjgup.mp4 with label FAKE
# Processed bqtuuwzdtr.mp4 with label FAKE
# Processed brhalypwoo.mp4 with label FAKE
# Processed brvqtabyxj.mp4 with label FAKE
# Processed brwrlczjvi.mp4 with label REAL
# Processed bseamdrpbj.mp4 with label FAKE
# Processed bsfmwclnqy.mp4 with label FAKE
# Processed bsqgziaylx.mp4 with label FAKE
# Processed btiysiskpf.mp4 with label FAKE
# Processed btjlfpzbdu.mp4 with label FAKE
# Processed btjwbtsgln.mp4 with label FAKE
# Processed btmsngnqhv.mp4 with label FAKE
# Processed btohlidmru.mp4 with label FAKE
# Processed btugrnoton.mp4 with label FAKE
# Processed btunxncpjh.mp4 with label FAKE
# Processed btxlttbpkj.mp4 with label FAKE
# Processed bulkxhhknf.mp4 with label REAL
# Processed bvgwelbeof.mp4 with label FAKE
# Processed bvzjkezkms.mp4 with label FAKE
# Processed bweezhfpzp.mp4 with label FAKE
# Processed bwhlgysghg.mp4 with label REAL
# Processed bwipwzzxxu.mp4 with label REAL
# Processed bwuwstvsbw.mp4 with label FAKE
# Processed bxzakyopjf.mp4 with label REAL
# Processed bydaidkpdp.mp4 with label FAKE
# Processed byfenovjnf.mp4 with label FAKE
# Processed byijojkdba.mp4 with label FAKE
# Processed byofowlkki.mp4 with label FAKE
# Processed byqzyxifza.mp4 with label FAKE
# Processed byunigvnay.mp4 with label FAKE
# Processed byyqectxqa.mp4 with label FAKE
# Processed bzmdrafeex.mp4 with label FAKE
# Processed bzythlfnhq.mp4 with label REAL
# Processed caifxvsozs.mp4 with label REAL
# Processed caqbrkogkb.mp4 with label FAKE
# Processed cbbibzcoih.mp4 with label FAKE
# Processed cbltdtxglo.mp4 with label FAKE
# Processed ccfoszqabv.mp4 with label REAL
# Processed ccmonzqfrz.mp4 with label FAKE
# Processed cdaxixbosp.mp4 with label FAKE
# Processed cdbsbdymzd.mp4 with label FAKE
# Processed cdphtzqrvp.mp4 with label FAKE
# Processed cdyakrxkia.mp4 with label FAKE
# Processed cepxysienc.mp4 with label FAKE
# Processed cettndmvzl.mp4 with label FAKE
# Processed ceymbecxnj.mp4 with label FAKE
# Processed cferslmfwh.mp4 with label FAKE
# Processed cffffbcywc.mp4 with label FAKE
# Processed cfxkpiweqt.mp4 with label REAL
# Processed cfyduhpbps.mp4 with label FAKE
# Processed cglxirfaey.mp4 with label FAKE
# Processed cgvrgibpfo.mp4 with label FAKE
# Processed chtapglbcj.mp4 with label REAL
# Processed chviwxsfhg.mp4 with label REAL
# Processed chzieimrwu.mp4 with label FAKE
# Processed ciyoudyhly.mp4 with label REAL
# Processed cizlkenljw.mp4 with label REAL
# Processed ckbdwedgmc.mp4 with label FAKE
# Processed ckjaibzfxa.mp4 with label REAL
# Processed ckkuyewywx.mp4 with label REAL
# Processed cknyxaqouy.mp4 with label FAKE
# Processed cksanfsjhc.mp4 with label FAKE
# Processed clihsshdkq.mp4 with label FAKE
# Processed clrycekyst.mp4 with label REAL
# Processed cmbzllswnl.mp4 with label REAL
# Processed cmxcfkrjiv.mp4 with label FAKE
# Processed cnilkgvfei.mp4 with label FAKE
# Processed coadfnerlk.mp4 with label FAKE
# Processed cobjrlugvp.mp4 with label REAL
# Processed covdcysmbi.mp4 with label FAKE
# Processed cpjxareypw.mp4 with label REAL
# Processed cppdvdejkc.mp4 with label REAL
# Processed cprhtltsjp.mp4 with label REAL
# Processed cqfugiqupm.mp4 with label FAKE
# Processed cqhngvpgyi.mp4 with label FAKE
# Processed cqrskwiqng.mp4 with label FAKE
# Processed crezycjqyk.mp4 with label REAL
# Processed crktehraph.mp4 with label FAKE
# Processed crzfebnfgb.mp4 with label FAKE
# Processed cthdnahrkh.mp4 with label FAKE
# Processed ctpqeykqdp.mp4 with label FAKE
# Processed cttqtsjvgn.mp4 with label FAKE
# Processed ctzmavwror.mp4 with label FAKE
# Processed curpwogllm.mp4 with label FAKE
# Processed cuzrgrbvil.mp4 with label FAKE
# Processed cvaksbpssm.mp4 with label FAKE
# Processed cwbacdwrzo.mp4 with label FAKE
# Processed cwqlvzefpg.mp4 with label FAKE
# Processed cwrtyzndpx.mp4 with label FAKE
# Processed cwsbspfzck.mp4 with label FAKE
# Processed cwwandrkus.mp4 with label FAKE
# Processed cxfujlvsuw.mp4 with label FAKE
# Processed cxrfacemmq.mp4 with label FAKE
# Processed cxttmymlbn.mp4 with label FAKE
# Processed cyboodqqyr.mp4 with label FAKE
# Processed cycacemkmt.mp4 with label FAKE
# Processed cyclgfjdrv.mp4 with label FAKE
# Processed cyxlcuyznd.mp4 with label REAL
# Processed czfunozvwp.mp4 with label FAKE
# Processed czkdanyadc.mp4 with label FAKE
# Processed czmqpxrqoh.mp4 with label FAKE
# Processed dafhtipaml.mp4 with label FAKE
# Processed dakiztgtnw.mp4 with label REAL
# Processed dakqwktlbi.mp4 with label FAKE
# Processed dbhoxkblzx.mp4 with label FAKE
# Processed dbhrpizyeq.mp4 with label FAKE
# Processed dbnygxtwek.mp4 with label REAL
# Processed dboxtiehng.mp4 with label FAKE
# Processed dbtbbhakdv.mp4 with label REAL
# Processed dbzcqmxzaj.mp4 with label FAKE
# Processed dbzpcjntve.mp4 with label FAKE
# Processed dcamvmuors.mp4 with label FAKE
# Processed dcuiiorugd.mp4 with label FAKE
# Processed ddepeddixj.mp4 with label REAL
# Processed ddhfabwpuz.mp4 with label FAKE
# Processed ddjggcasdw.mp4 with label FAKE
# Processed ddpvuimigj.mp4 with label FAKE
# Processed ddqccgmtka.mp4 with label FAKE
# Processed degpbqvcay.mp4 with label FAKE
# Processed deywhkarol.mp4 with label FAKE
# Processed deyyistcrd.mp4 with label FAKE
# Processed dfbpceeaox.mp4 with label FAKE
# Processed dgmevclvzy.mp4 with label FAKE
# Processed dgxrqjdomn.mp4 with label FAKE
# Processed dgzklxjmix.mp4 with label FAKE
# Processed dhcndnuwta.mp4 with label REAL
# Processed dhcselezer.mp4 with label FAKE
# Processed dhevettufk.mp4 with label FAKE
# Processed dhjmzhrcav.mp4 with label FAKE
# Processed dhkwmjxwrn.mp4 with label FAKE
# Processed dhoqofwoxa.mp4 with label FAKE
# Processed dhxctgyoqj.mp4 with label REAL
# Processed diomeixhrg.mp4 with label FAKE
# Processed diopzaywor.mp4 with label FAKE
# Processed diqraixiov.mp4 with label FAKE
# Processed diuzrpqjli.mp4 with label FAKE
# Processed djvtbgwdcc.mp4 with label FAKE
# Processed djvutyvaio.mp4 with label FAKE
# Processed djxdyjopjd.mp4 with label REAL
# Processed dkdwxmtpuo.mp4 with label FAKE
# Processed dkhlttuvmx.mp4 with label FAKE
# Processed dkrvorliqc.mp4 with label FAKE
# Processed dkuayagnmc.mp4 with label REAL
# Processed dkwjwbwgey.mp4 with label FAKE
# Processed dkzvdrzcnr.mp4 with label REAL
# Processed dlpoieqvfb.mp4 with label REAL
# Processed dlrsbscitn.mp4 with label FAKE
# Processed dnexlwbcxq.mp4 with label FAKE
# Processed dnhvalzvrt.mp4 with label FAKE
# Processed dntkzzzcdh.mp4 with label FAKE
# Processed dnyvfblxpm.mp4 with label FAKE
# Processed doanjploai.mp4 with label FAKE
# Processed dofusvhnib.mp4 with label FAKE
# Processed dozyddhild.mp4 with label FAKE
# Processed dptbnjnkdg.mp4 with label FAKE
# Processed dptrzdvwpg.mp4 with label FAKE
# Processed dqnyszdong.mp4 with label FAKE
# Processed dqppxmoqdl.mp4 with label FAKE
# Processed dqqtjcryjv.mp4 with label FAKE
# Processed dqswpjoepo.mp4 with label FAKE
# Processed dqzreruvje.mp4 with label FAKE
# Processed drcyabprvt.mp4 with label REAL
# Processed drgjzlxzxj.mp4 with label FAKE
# Processed drsakwyvqv.mp4 with label FAKE
# Processed drtbksnpol.mp4 with label FAKE
# Processed dsdoseflas.mp4 with label FAKE
# Processed dsgpbgsrdm.mp4 with label FAKE
# Processed dsjbknkujw.mp4 with label REAL
# Processed dsndhujjjb.mp4 with label FAKE
# Processed dtbpmdqvao.mp4 with label FAKE
# Processed dtocdfbwca.mp4 with label FAKE
# Processed dubiroskqn.mp4 with label FAKE
# Processed dulanfulol.mp4 with label FAKE
# Processed duvyaxbzvp.mp4 with label FAKE
# Processed duycddgtrl.mp4 with label REAL
# Processed duzuusuajr.mp4 with label FAKE
# Processed dvakowbgbt.mp4 with label FAKE
# Processed dvumqqhoac.mp4 with label FAKE
# Processed dwediigjit.mp4 with label FAKE
# Processed dxbqjxrhin.mp4 with label REAL
# Processed dxuliowugt.mp4 with label FAKE
# Processed dxuplhwvig.mp4 with label FAKE
# Processed dzieklokdr.mp4 with label FAKE
# Processed dzqwgqewhu.mp4 with label FAKE
# Processed dzvyfiarrq.mp4 with label FAKE
# Processed dzwkmcwkwl.mp4 with label FAKE
# Processed dzyuwjkjui.mp4 with label REAL
# Processed eahlqmfvtj.mp4 with label FAKE
# Processed eajlrktemq.mp4 with label FAKE
# Processed ebchwmwayp.mp4 with label FAKE
# Processed ebebgmtlcu.mp4 with label FAKE
# Processed ebeknhudxq.mp4 with label FAKE
# Processed ebkzwjgjhq.mp4 with label FAKE
# Processed ebywfrmhtd.mp4 with label FAKE
# Processed eckvhdusax.mp4 with label REAL
# Processed ecnihjlfyt.mp4 with label FAKE
# Processed ecujsjhscd.mp4 with label REAL
# Processed ecuvtoltue.mp4 with label FAKE
# Processed ecwaxgutkc.mp4 with label FAKE
# Processed eczrseixwq.mp4 with label FAKE
# Processed edyncaijwx.mp4 with label REAL
# Processed eebrkicpry.mp4 with label FAKE
# Processed eebserckhh.mp4 with label FAKE
# Processed eejswgycjc.mp4 with label FAKE
# Processed eekozbeafq.mp4 with label FAKE
# Processed eepezmygaq.mp4 with label FAKE
# Processed eeyhxisdfh.mp4 with label FAKE
# Processed efdyrflcpg.mp4 with label FAKE
# Processed efwfxwwlbw.mp4 with label REAL
# Processed egbbcxcuqy.mp4 with label FAKE
# Processed eggbjzxnmg.mp4 with label REAL
# Processed egghxjjmfg.mp4 with label REAL
# Processed ehbnclaukr.mp4 with label FAKE
# Processed ehccixxzoe.mp4 with label REAL
# Processed ehdkmxgtxh.mp4 with label FAKE
# Processed ehevsxtecd.mp4 with label FAKE
# Processed ehfiekigla.mp4 with label FAKE
# Processed ehieahnhte.mp4 with label FAKE
# Processed ehtdtkmmli.mp4 with label REAL
# Processed eiriyukqqy.mp4 with label FAKE
# Processed eivxffliio.mp4 with label FAKE
# Processed eiwopxzjfn.mp4 with label FAKE
# Processed eixwxvxbbn.mp4 with label FAKE
# Processed ejkqesyvam.mp4 with label FAKE
# Processed ekcrtigpab.mp4 with label REAL
# Processed ekhacizpah.mp4 with label FAKE
# Processed ekkdjkirzq.mp4 with label FAKE
# Processed elginszwtk.mp4 with label FAKE
# Processed ellavthztb.mp4 with label REAL
# Processed elvvackpjh.mp4 with label FAKE
# Processed emaalmsonj.mp4 with label FAKE
# Processed emfbhytfhc.mp4 with label FAKE
# Processed emgjphonqb.mp4 with label FAKE
# Processed ensyyivobf.mp4 with label FAKE
# Processed eoewqcpbgt.mp4 with label FAKE
# Processed eprybmbpba.mp4 with label FAKE
# Processed epymyyiblu.mp4 with label FAKE
# Processed eqjscdagiv.mp4 with label FAKE
# Processed eqnoqyfquo.mp4 with label REAL
# Processed eqvuznuwsa.mp4 with label FAKE
# Processed erlvuvjsjf.mp4 with label REAL
# Processed erqgqacbqe.mp4 with label FAKE
# Processed errocgcham.mp4 with label FAKE
# Processed esckbnkkvb.mp4 with label FAKE
# Processed esgftaficx.mp4 with label FAKE
# Processed esnntzzajv.mp4 with label FAKE
# Processed esxrvsgpvb.mp4 with label FAKE
# Processed esyhwdfnxs.mp4 with label FAKE
# Processed esyrimvzsa.mp4 with label FAKE
# Processed etdcqxabww.mp4 with label FAKE
# Processed etejaapnxh.mp4 with label FAKE
# Processed etmcruaihe.mp4 with label FAKE
# Processed etohcvnzbj.mp4 with label FAKE
# Processed eudeqjhdfd.mp4 with label REAL
# Processed eukvucdetx.mp4 with label FAKE

# %%
|
